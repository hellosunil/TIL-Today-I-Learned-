# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import csv
import time
from bs4 import BeautifulSoup
import urllib.request
import requests
import urllib
import json
import re
import os
import sys
import json
import re
import konlpy
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import os
import sys
import urllib.request
import json
import re
import pandas as pd
import networkx as nx
plt.rc('font', family='NanumGothic')
# %matplotlib inline

# %%
client_id = "4FdY0qL5azIJ4BXVjUal"
client_secret = "Ylgg4Oh_FN"
search = input('검색어를 입력하세요 : ')

blog_data = pd.DataFrame()

encText = urllib.parse.quote(search)

title = list()
description = list()
adress = list()

for i in range(1, 1000, 100):
    try:
        url = "https://openapi.naver.com/v1/search/blog?query=" + encText + '&display=100'+'&sort=sim'+f'&start={i}' # json 결과
        # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
        response = urllib.request.urlopen(request)
        rescode = response.getcode()

        if(rescode==200):
            response_body = response.read().decode('utf-8')
            response_body1 = json.loads(str(response_body))
            for i in response_body1['items']:
                hangul = re.compile('[^ ㄱ-ㅎ|가-힣]+')
                title.append(hangul.sub(r'', i['title']))
                description.append(hangul.sub(r'', i['description']))
                adress.append(i['link'])
        else:
            print("Error Code:" + rescode)

    except:
        print('Error')

blog_data['title'] = title
blog_data['description']= description
blog_data['adress'] = adress

blog_data
# Out:
# 검색어를 입력하세요 : 커피
#                                 title  \
# 0              정동길카페  라운드앤드 커피 디저트 맛집
# 1                  강릉 중앙시장 선물 커피빵 엄지척
# 2               부산 기장 카페 가볼만한곳 공극샌드커피
# 3               가정용커피머신기 드립캡슐    라이녹스
# 4                     풍미깊었던 제주도 커피 맛집
# ..                                ...
# 995  에스프레소머신 청소하기 테팔 에스프레소머신 커피메이커 청소
# 996        블로그씨   캔커피 믹스커피  특히 라떼 류를
# 997         아차산카페 푸쉬커피 버글러커피바 신토불이떡볶이
# 998                    성수동 카페 로우커피스탠드
# 999    시청카페 서울 전망좋은 카페 커피앤시가렛 카페 솔직후기
#
#                                            description  \
# 0    정동길카페  라운드앤드 커피 디저트 맛집 파란 하늘과 녹색 나무들 너무나 예쁜 정동...
# 1    강릉 중앙시장 선물 커피빵 엄지척 며칠 전 친구가 아이들을 데리고 강릉에 간다길래 ...
# 2    공극샌드커피 지난번까지 다른 카페에 주로 갔었는데 이번엔 새로운 곳에 한번 가보자며...
# 3    가정용커피머신기 라이녹스 현대인답게 하루에 보통 잔의 커피를 마시고 있다 그렇다 보...
# 4    얼마 전 친구와 제주도로 놀러 갔다가 에서 유명세를 탄 제주도 커피 맛집을 찾았다 ...
# ..                                                 ...
# 995  그리고 커피맛도 더 좋아진다고하니 시작해볼께요 저희는 테팔 수동에스프레소머신을 사용...
# 996  커피에 대한 내용입니다 저는 기본적으로 하루에 컵잔 아님 이상은 마시며 양으로 환산...
# 997  아차산카페 푸쉬커피 버글러커피바 신토불이떡볶이 은서의 유치원 여름방학 기간에는 친정...
# 998  성수동 로우커피스탠드는 정말 많이 갔는데 이제서야 포스팅 하네요 ㅎㅎ 로우커피스탠드...
# 999  가오픈 한다고 했을때 부터 가보고 싶었던 커피앤시가렛 드디어 가봤다 오피스 한복판 ...
#
#                                                 adress
# 0    https://blog.naver.com/miyaism?Redirect=Log&lo...
# 1    https://blog.naver.com/woaiheejun?Redirect=Log...
# 2    https://blog.naver.com/80sunjin?Redirect=Log&l...
# 3    https://blog.naver.com/lubkhaki?Redirect=Log&l...
# 4    https://blog.naver.com/hloveh01?Redirect=Log&l...
# ..                                                 ...
# 995  https://blog.naver.com/kojs53?Redirect=Log&log...
# 996  https://blog.naver.com/newpark314?Redirect=Log...
# 997  https://blog.naver.com/cider99?Redirect=Log&lo...
# 998  https://blog.naver.com/vividirene?Redirect=Log...
# 999  https://blog.naver.com/kha122412?Redirect=Log&...
#
# [1000 rows x 3 columns]

# %%
data = []
for i in blog_data['description']:
    data.append(i)
    
print(data)
# Out:
# ['정동길카페  라운드앤드 커피 디저트 맛집 파란 하늘과 녹색 나무들 너무나 예쁜 정동길  걷기만 왜냐면 빵이랑 커피가 진짜 너무 맛있었기 때문이닷  맛있는데 건강하기까지한 빵이었어   ', '강릉 중앙시장 선물 커피빵 엄지척 며칠 전 친구가 아이들을 데리고 강릉에 간다길래 오랜만에 옆쪽에는 커피빵을 파는 강릉당이 있었답니다 민트색의 간판에 카페에서 봤음직한 조명이 장착되어있어 ', '공극샌드커피 지난번까지 다른 카페에 주로 갔었는데 이번엔 새로운 곳에 한번 가보자며 ㅎㅎ 노란 파라솔이 인상깊었던 분위기 좋은 카페  부산 기장 카페 가볼만한곳 공극샌드커피 글사진 이름부터 ', '가정용커피머신기 라이녹스 현대인답게 하루에 보통 잔의 커피를 마시고 있다 그렇다 보니 당연히 몇 번이나 가정용커피머신기 구입을 고려했더랬다 하지만 예전엔 일주일에 보통 번 외출을 했기 ', '얼마 전 친구와 제주도로 놀러 갔다가 에서 유명세를 탄 제주도 커피 맛집을 찾았다 신선한 식재료로 곧장 제주도 커피 맛집의 메뉴판을 살펴보기 시작했다 각종 디저트는 몰론이고 음료도 다양했다 ', '부산 달맞이고개 카페 라이프커피앤티  글사진  션니블로그 안녕하세요 션니에오 오랜만에 라이프커피앤티 비아인키노란 가구를 중심으로 책과 커피 여백과 컬러 등 삶을 구성하는 요소들을 ', '섬유유연제 구매하면서 제가 평소 좋아하던 케냐 원두가 담긴 드립백 커피도 판매하길래 사봤는데요 저렴한 가격에 비해 맛과 향이 특히 좋은 것 같아 추천해볼까 해여 바로 여기커피 드립백인데요 상자에 ', '이처럼 커피에 대해 재미난 말들이 참 많은데요 아무래도 요즘은 주변에 카페도 많고 다양한 커피음료가 많은 만큼 커피를 좋아하는 인구가 더더욱 늘어나고 있기 때문이 아닐까해요 저 또한 커피를 워낙 ', '일산 가성비 좋은 포트캔커피  폭탄카스테라 일산 라페스타 쪽에 갔다가 오픈 이벤트를ㅇ하고 있어서 무조건 들어가게 되었던 포트캔커피 라페스타점 인데요 이날하고 다음날까지 스페셜티커피 를 ', '홈카페에 빠질 수 없는 커피 저는 커피 캡슐을 통해 에스프레소를 추출하는 커피 머신을 사용하고 있는데요 제조사에 따라 다르지만 대부분의 커피 캡슐은 비닐 커피 플라스틱 등의 여러 소재로 ', '제가 첫째때는 딱히 아는게 없어서 분유도 전기 커피포트를 이용해서 타서 먹이고는 했었거든요 사실 첫째때는 전기 커피포트 이용해서 물을 끓인 후에 식혀서 분유를 타다 보니까 생각보다 손이 많이 가고 ', '향긋한 커피향이 가득가득 레벨링이 잘된 원두는 맞춰진 시간안에 정량이 정확하게 추출이 된다고 선생님은 커피일을 오래 하셔서 이미 손목이 많이 좋지 않다고 하신다 카페에 가서 커피 빨리 주세요 왜 제 ', '을지로를 돌아다니다 보면 호랑이 그림이 그려진 커피를 들고 다니는 분들을 심심치 않게 발견할 수 있어요 바로 대림상가에서 제일 핫한 카페라고 해도 과언이 아닌 호랑이커피인데요 오랜만에 나들이를 ', '평소에도 커피에 굉장히 관심이 많고 즐겨 마시던 저는 다양한 카페를 돌아다니는 취미도 있었어요 각 매장마다 취급하는 원두가 다르고 추출방식이 다르기 때문에 당연히 커피 한 잔을 먹더라도 다른 느낌이 ', '안녕하세요 동그리 입니다  이번 포스팅은 연남동에 자리한 커피 페어링 코스를 맛볼 수 있는 곳 코스로 커피 오마카세 커피 페어링 코스로 알려진 곳이더라구요 예약시간보다 분 정도 일찍 ', '어진동 카페  테라로사 세종점 오늘도 어김없이 하루를 커피로 시작 어진동 카페 테라로사 세종점은 곳과 커피를 마시는 곳이 있당 굿즈를 보면 매번 비슷해도 구경해야행ㅋㅋㅋㅋㅋ 굿즈 진열 공간에는 ', '이런 날씨에는 커피가 훅 땡기게 마련이잖아요 여름에는 얼음 동동 띄워서 물처럼 호로록 마셔댔다면 가을에는 말입니다 뜨끈한 커피를 홀짝거리믄서 창밖도 함 보고 하믄서 분위기를 잡게 되는 그런 ', '전부터 오며가며 많이 봐서 꼭 가봐야지 했는데 드디어 ㅋㅋ 방문해본 곳 스위스 워터 커피 삼성동 많더라 커피콩들 꽤나 넓고 유니트한 가구들 유럽감성같은 느낌 원두에 따라 글라인더도 다르게 ', '커피줄루와 함께 한다면 더 뜻깊은 날들을 만들 수 있을 거라고 생각하는데요 이번에는 경남지식인재개발원에서 반자동 커피 머신인 시모넬리를 대 설치하고 왔답니다 지금부터 그 현장으로 함께 가볼까요 ', '예쁜 전시품도 보고 맛있는 커피도 마실 수 있어서 정말 좋았던 시간이었어요 이번에 다녀온 대구 넓고 큰 통유리창 너머로 예쁜 풍경이 펼쳐져 있어서 커피를 마시며 여유로운 시간을 보내기에 딱 적합한 ', '색다르고 맛있는 궁합 전참시 아보카도커피 저도 먹어봤습니다 먹어보니 세상 잘 어울리는 최강 궁합이네요 하루종일 든든하기까지 제 스타일이었어요 전참시 세븐 아보카도커피가 핫하군요 궁금해서 저도 ', '바다 산 장치 그리고 커피 등등 그 중에서도 강릉 커피문화를 시작했다는 강릉 테라로사 본점을 다녀와봤어요 입구부터 뭔가 웅장한 느낌 커피 공장이자 커피 박물관이란 느낌이 확 왔어요 테라로사 ', '요즘 집에서 보내는 시간이 늘면서 핸드드립이나 커피 머신을 이용해 직접 커피 원두를 내려 먹는 사람들이 늘고 있다 커피 원두에는 항산화 성분인 클로로젠산 성분이 들어 있어 체지방 분해를 돕고 지방 ', '청도 로카커피 카페 폭포와 백일홍 그리고 해바라기 게다가 산속에 둘러싸여서 숲속 카페 컨셉에 아주 충실하더라 로카커피  경상북도 청도에 위치한 카페  영업시간  월금 시시  토 시시  일 ', '커피선물세트 도로시커피팩토리 블랜딩커피 결혼하고나서 거실에 메인으로 홈카페 차리고 최소 하루에 한 잔은 커피 마시며 지내는 인 캡슐커피머신부터 모카포트 드립장비 등등 하나씩 모으다보니 이제는 ', '집에 있는 시간이 늘어나고 카페에서 커피를 즐기지 못하는 시간이 길어지다보니ㅎ 가정용 커피머신을 하나 장만하고 싶어졌어요 저희집은 식구가 많아서 버튼만 누르면 커피가 나오는 편리하고 사용이 ', '디어커피    용인 기흥 흥덕로 카페 광교 근처 카페추천 안녕하세요 토리예요 주말에 아이들과 광교 아쿠아플라넷 갔다가 차로분정도 이동하여 용인 기흥구 흥덕 디어커피 카페에 다녀왔어요 ', '여러분 혹시 방탄커피라고 들어보셨나요 얼마 전 프로그램에서 개그맨 부부가 식사 후 칼로리 소비를 위해 방탄커피를 만들어 먹는 것이 화제가 됐죠 다이어트에 민감한 연예인들 사이에서도 핫할 만큼 ', '안녕하세요 민스맘이에요 집에서 과일을 먹거나 간단한 디저트 혹은 카페 음료를 만들 때 가장 유용하게 쓰는 건 바로 커피숟가락  티스푼이라 생각해요 가만히 놔두면 가라앉는 과일주스나 커피 차를 ', '호두강정 레시피 기태영 믹스커피 호두강정 초간단 디저트 남편이 일찍 퇴근하는 편이라 저녁을 일찍 씨가 커피믹스로 호두강정을 만드는 걸 보고는 커피믹스를 넣어 커피 맛이 나는 호두 강정의 맛도 ', '커피전동그라인더 무선 그라인더라서 휴대성 좋은 마리슈타이거 루미 살랑살랑 시원한 바람이 불어오는 요즘 피크닉이든 캠핑이든 떠나고 싶어지는 마음이 한가득인 요즘 카페인은 끊을 수 없지  커피는 ', '커피 다들 좋아하시죠 주는사랑이 오늘은 콜드브루 커피 추천도 할겸 챠스빈커피로 손쉽게 아이스아메리카노 아이스 카페라떼 만들기 올려봅니다 제가 엄청 애정하는 아이스라떼와 울 옆지기가 좋아하는 ', '세븐 아보카도커피 최애하는 아보카도 먹는법 원픽될 듯 개인적으로 몇해전부터 이 맛을 차츰차츰 하고 말았던 아보카도커피를 오늘 맛봤답니다 세상에나 아보카도 좋아한다면 이 맛은 꼭 ', '교동카페 헤이트커피 라떼맛집대구감성카페네 안녕하세요 딩입니다 아시져 주말마다 커피나들이 가는거 ㅋㅋㅋㅋㅋㅋㅋㅋ 오늘도 어김없이 커피 찾아 삼만리 하고 왔는데 가는 곳 마다 사람이 ', '그대로 그냥 출근 ㅎㅎ 커피여왕 김해커피여왕 아침을 일찍 먹어서 배고프다 나만 먹는 뻥튀기 몇개 먹고 커피여왕에서 커피 시켜서 나눠마시고 나는 아이스카페라떼 여기 커피 찐하고 꼬소하니 ', '아침에 상쾌한 공기를 마시며 커피를 들고 싶었다 그렇게 마주하게 된 나의 첫 커피 장비 국내 제작 핸드 드립 커피 세트 나와 커피는 뗄 수 없는 연분의 관계 해서 이번에 고상하게 커피도 내려 먹자고 ', '비가 추적추적 내렸던 주말 여유롭게 커피마시는 시간을 보내고 싶어 찾 ...

# %%
from konlpy.tag import Komoran

def tag_contents(contents):
    tag_result = []
    ma = Komoran()
    
    for i in contents:
        ma_content = ma.pos(i)
        tag_result.append(ma_content)
    return tag_result
        
ma_result = tag_contents(data)

# %%
FILTER=['NNG', 'NNP', "XR"]
STOPWORD =['으로', '어요', '니다', '이', '닷', '용', '공', '극', '드', '곳', '션', '오', '동', '포']
RESULT = []

def tag_result_select(ma_result,FILTER,STOPWORD):
    for i in ma_result:
        tag_result = []
        for j, k in i:
            if k in FILTER and j not in STOPWORD:
                tag_result.append(j)
        RESULT.append(tag_result)
    return RESULT

tdata = tag_result_select(ma_result,FILTER,STOPWORD)

# %%
from collections import Counter
from itertools import combinations

def word_matrics(tdata):
    word_count = Counter()
    for i in tdata:
        for word1, word2 in combinations(i, 2):
            if len(word1) ==1 or len(word2) ==1:
                continue
            if word1==word2:
                continue
            elif word_count[(word1, word2)] >=1:
                word_count[(word1, word2)] +=1
            else:
                word_count[(word1, word2)] =1
    return word_count

wresult = word_matrics(tdata)

# %%
graphdata = []
for i in wresult:
    data = (i[0], i[1], wresult[i])
    graphdata.append(data)
graphdata
# Out:
# [('정동', '카페', 4),
#  ('정동', '라운드', 1),
#  ('정동', '앤드', 1),
#  ('정동', '커피', 2),
#  ('정동', '디저트', 1),
#  ('정동', '맛집', 1),
#  ('정동', '파란', 1),
#  ('정동', '하늘', 1),
#  ('정동', '녹색', 1),
#  ('정동', '나무', 1),
#  ('정동', '정동기', 1),
#  ('정동', '걷기', 1),
#  ('정동', '이랑', 1),
#  ('정동', '건강', 1),
#  ('카페', '라운드', 1),
#  ('카페', '앤드', 1),
#  ('카페', '커피', 678),
#  ('카페', '디저트', 26),
#  ('카페', '맛집', 12),
#  ('카페', '파란', 3),
#  ('카페', '하늘', 3),
#  ('카페', '녹색', 1),
#  ('카페', '나무', 6),
#  ('카페', '정동기', 1),
#  ('카페', '걷기', 1),
#  ('카페', '이랑', 9),
#  ('카페', '건강', 1),
#  ('라운드', '앤드', 1),
#  ('라운드', '커피', 20),
#  ('라운드', '디저트', 1),
#  ('라운드', '맛집', 1),
#  ('라운드', '파란', 1),
#  ('라운드', '하늘', 1),
#  ('라운드', '녹색', 1),
#  ('라운드', '나무', 1),
#  ('라운드', '정동기', 1),
#  ('라운드', '걷기', 1),
#  ('라운드', '이랑', 1),
#  ('라운드', '건강', 1),
#  ('앤드', '커피', 2),
#  ('앤드', '디저트', 1),
#  ('앤드', '맛집', 1),
#  ('앤드', '파란', 1),
#  ('앤드', '하늘', 1),
#  ('앤드', '녹색', 1),
#  ('앤드', '나무', 1),
#  ('앤드', '정동기', 1),
#  ('앤드', '걷기', 1),
#  ('앤드', '이랑', 1),
#  ('앤드', '건강', 1),
#  ('커피', '디저트', 54),
#  ('커피', '맛집', 50),
#  ('커피', '파란', 3),
#  ('커피', '하늘', 6),
#  ('커피', '녹색', 1),
#  ('커피', '나무', 7),
#  ('커피', '정동기', 1),
#  ('커피', '걷기', 1),
#  ('커피', '이랑', 9),
#  ('커피', '건강', 10),
#  ('디저트', '맛집', 2),
#  ('디저트', '파란', 1),
#  ('디저트', '하늘', 1),
#  ('디저트', '녹색', 1),
#  ('디저트', '나무', 1),
#  ('디저트', '정동기', 1),
#  ('디저트', '걷기', 1),
#  ('디저트', '이랑', 2),
#  ('디저트', '커피', 41),
#  ('디저트', '건강', 1),
#  ('맛집', '파란', 1),
#  ('맛집', '하늘', 1),
#  ('맛집', '녹색', 1),
#  ('맛집', '나무', 1),
#  ('맛집', '정동기', 1),
#  ('맛집', '걷기', 1),
#  ('맛집', '이랑', 1),
#  ('맛집', '커피', 62),
#  ('맛집', '건강', 1),
#  ('파란', '하늘', 1),
#  ('파란', '녹색', 1),
#  ('파란', '나무', 1),
#  ('파란', '정동기', 1),
#  ('파란', '걷기', 1),
#  ('파란', '이랑', 1),
#  ('파란', '커피', 1),
#  ('파란', '건강', 1),
#  ('하늘', '녹색', 1),
#  ('하늘', '나무', 1),
#  ('하늘', '정동기', 1),
#  ('하늘', '걷기', 1),
#  ('하늘', '이랑', 1),
#  ('하늘', '커피', 9),
#  ('하늘', '건강', 1),
#  ('녹색', '나무', 1),
#  ('녹색', '정동기', 1),
#  ('녹색', '걷기', 1),
#  ('녹색', '이랑', 1),
#  ('녹색', '커피', 1),
#  ('녹색', '건강', 1),
#  ('나무', '정동기', 1),
#  ('나무', '걷기', 1),
#  ('나무', '이랑', 1),
#  ('나무', '커피', 7),
#  ('나무', '건강', 1),
#  ('정동기', '걷기', 1),
#  ('정동기', '이랑', 1),
#  ('정동기', '커피', 1),
#  ('정동기', '건강', 1),
#  ('걷기', '이랑', 1),
#  ('걷기', '커피', 1),
#  ('걷기', '건강', 1),
#  ('이랑', '커피', 13),
#  ('이랑', '건강', 1),
#  ('강릉', '중앙시장', 4),
#  ('강릉', '선물', 6),
#  ('강릉', '커피', 68),
#  ('강릉', '엄지', 1),
#  ('강릉', '며칠', 1),
#  ('강릉', '친구', 1),
#  ('강릉', '아이', 1),
#  ('강릉', '간다', 2),
#  ('강릉', '오랜만', 3),
#  ('강릉', '옆쪽', 2),
#  ('강릉', '민트', 3),
#  ('강릉', '간판', 3),
#  ('강릉', '카페', 21),
#  ('강릉', '조명', 3),
#  ('강릉', '장착', 3),
#  ('중앙시장', '선물', 1),
#  ('중앙시장', '커피', 2),
#  ('중앙시장', '엄지', 1),
#  ('중앙시장', '며칠', 1),
#  ('중앙시장', '친구', 1),
#  ('중앙시장', '아이', 1),
#  ('중앙시장', '강릉', 2),
#  ('중앙시장', '간다', 1),
#  ('중앙시장', '오랜만', 1),
#  ('중앙시장', '옆쪽', 1),
#  ('중앙시장', '민트', 1),
#  ('중앙시장', '간판', 1),
#  ('중앙시장', '카페', 1),
#  ('중앙시장', '조명', 1),
#  ('중앙시장', '장착', 1),
#  ('선물', '커피', 74),
#  ('선물', '엄지', 1),
#  ('선물', '며칠', 1),
#  ('선물', '친구', 1),
#  ('선물', '아이', 1),
#  ('선물', '강릉', 9),
#  ('선물', '간다', 1),
#  ('선물', '오랜만', 1),
#  ('선물', '옆쪽', 1),
#  ('선물', '민트', 1),
#  ('선물', '간판', 1),
#  ('선물', '카페', 8),
#  ('선물', '조명', 1),
#  ('선물', '장착', 1),
#  ('커피', '엄지', 1),
#  ('커피', '며칠', 5),
#  ('커피', '친구', 24),
#  ('커피', '아이', 20),
#  ('커피', '강릉', 46),
#  ('커피', '간다', 1),
#  ('커피', '오랜만', 29),
#  ('커피', '옆쪽', 3),
#  ('커피', '민트', 3),
#  ('커피', '간판', 12),
#  ('커피', '카페', 543),
#  ('커피', '조명', 5),
#  ('커피', '장착', 2),
#  ('엄지', '며칠', 1),
#  ('엄지', '친구', 1),
#  ('엄지', '아이', 1),
#  ('엄지', '강릉', 2),
#  ('엄지', '간다', 1),
#  ('엄지', '오랜만', 1),
#  ('엄지', '옆쪽', 1),
#  ('엄지', '커피', 1),
#  ('엄지', '민트', 1),
#  ('엄지', '간판', 1),
#  ('엄지', '카페', 1),
#  ('엄지', '조명', 1),
#  ('엄지', '장착', 1),
#  ('며칠', '친구', 1),
#  ('며칠', '아이', 1),
#  ('며칠', '강릉', 2),
#  ('며칠', '간다', 1),
#  ('며칠', '오랜만', 1),
#  ('며칠', '옆쪽', 1),
#  ('며칠', '커피', 10),
#  ('며칠', '민트', 1),
#  ('며칠', '간판', 1),
#  ('며칠', '카페', 3),
#  ('며칠', '조명', 1),
#  ('며칠', '장착', 1),
#  ('친구', '아이', 2),
#  ('친구', '강릉', 2),
#  ('친구', '간다', 1),
#  ('친구', '오랜만', 2),
#  ('친구', '옆쪽', 1),
#  ('친구', '커피', 34),
#  ('친구', '민트', 1),
#  ('친구', '간판', 1),
#  ('친구', '카페', 9),
#  ('친구', '조명', 1),
#  ('친구', '장착', 1),
#  ('아이', '강릉', 2),
#  ('아이', '간다', 1),
#  ('아이', '오랜만', 2),
#  ('아이', '옆쪽', 1),
#  ('아이', '커피', 12),
#  ('아이', '민트', 1),
#  ('아이', '간판', 1),
#  ('아이', '카페', 1),
#  ('아이', '조명', 1),
#  ('아이', '장착', 1),
#  ('간다', '오랜만', 1),
#  ('간다', '옆쪽', 1),
#  ('간다', '커피', 3),
#  ('간다', '강릉', 1),
#  ('간다', '민트', 1),
#  ('간다', '간판', 1),
#  ('간다', '카페', 2),
#  ('간다', '조명', 1),
#  ('간다', '장착', 1),
#  ('오랜만', '옆쪽', 1),
#  ('오랜만', '커피', 20),
#  ('오랜만', '강릉', 3),
#  ('오랜만', '민트', 1),
#  ('오랜만', '간판', 1),
#  ('오랜만', '카페', 9),
#  ('오랜만', '조명', 1),
#  ('오랜만', '장착', 1),
#  ('옆쪽', '커피', 1),
#  ('옆쪽', '강릉', 1),
#  ('옆쪽', '민트', 1),
#  ('옆쪽', '간판', 1),
#  ('옆쪽', '카페', 1),
#  ('옆쪽', '조명', 1),
#  ('옆쪽', '장착', 1),
#  ('민트', '간판', 1),
#  ('민트', '카페', 1),
#  ('민트', '조명', 1),
#  ('민트', '장착', 1),
#  ('간판', '카페', 4),
#  ('간판', '조명', 2),
#  ('간판', '장착', 1),
#  ('카페', '조명', 2),
#  ('카페', '장착', 1),
#  ('조명', '장착', 1),
#  ('커피', '지난번', 3),
#  ('커피', '이번', 51),
#  ('커피', '파라솔', 1),
#  ('커피', '인상', 8),
#  ('커피', '분위기', 46),
#  ('커피', '부산', 19),
#  ('커피', '기장', 10),
#  ('커피', '한곳', 4),
#  ('커피', '사진', 57),
#  ('커피', '이름', 32),
#  ('지난번', '카페', 7),
#  ('지난번', '이번', 1),
#  ('지난번', '파라솔', 1),
#  ('지난번', '인상', 1),
#  ('지난번', '분위기', 1),
#  ('지난번', '부산', 1),
#  ('지난번', '기장', 1),
#  ('지난번', '한곳', 1),
#  ('지난번', '커피', 7),
#  ('지난번', '사진', 1),
#  ('지난번', '이름', 1),
#  ('카페', '이번', 17),
#  ('카페', '파라솔', 1),
#  ('카페', '인상', 2),
#  ('카페', '분위기', 21),
#  ('카페', '부산', 7),
#  ('카페', '기장', 4),
#  ('카페', '한곳', 4),
#  ('카페', '사진', 17),
#  ('카페', '이름', 16),
#  ('이번', '파라솔', 1),
#  ('이번', '인상', 1),
#  ('이번', '분위기', 3),
#  ('이번', '카페', 11),
#  ('이번', '부산', 1),
#  ('이번', '기장', 1),
#  ('이번', '한곳', 1),
#  ('이번', '커피', 60),
#  ('이번', '사진', 1),
#  ('이번', '이름', 3),
#  ('파라솔', '인상', 1),
#  ('파라솔', '분위기', 1),
#  ('파라솔', '카페', 2),
#  ('파라솔', '부산', 1),
#  ('파라솔', '기장', 1),
#  ('파라솔', '한곳', 1),
#  ('파라솔', '커피', 1),
#  ('파라솔', '사진', 1),
#  ('파라솔', '이름', 1),
#  ('인상', '분위기', 1),
#  ('인상', '카페', 3),
#  ('인상', '부산', 1),
#  ('인상', '기장', 1),
#  ('인상', '한곳', 1),
#  ('인상', '커피', 4),
#  ('인상', '사진', 1),
#  ('인상', '이름', 1),
#  ('분위기', '카페', 24),
#  ('분위기', '부산', 2),
#  ('분위기', '기장', 1),
#  ('분위기', '한곳', 1),
#  ('분위기', '커피', 26),
#  ('분위기', '사진', 1),
#  ('분위기', '이름', 3),
#  ('부산', '기장', 4),
#  ('부산', '카페', 13),
#  ('부산', '한곳', 1),
#  ('부산', '커피', 25),
#  ('부산', '사진', 2),
#  ('부산', '이름', 1),
#  ('기장', '카페', 12),
#  ('기장', '한곳', 1),
#  ('기장', '커피', 10),
#  ('기장', '사진', 1),
#  ('기장', '이름', 2),
#  ('한곳', '커피', 7),
#  ('한곳', '사진', 1),
#  ('한곳', '이름', 1),
#  ('사진', '이름', 2),
#  ('가정', '커피', 16),
#  ('가정', '머신', 14),
#  ('가정', '라이', 1),
#  ('가정', '녹스', 1),
#  ('가정', '현대인', 1),
#  ('가정', '하루', 1),
#  ('가정', '보니', 1),
#  ('가정', '구입', 2),
#  ('가정', '고려', 2),
#  ('가정', '예전', 2),
#  ('가정', '일주일', 2),
#  ('가정', '외출', 3),
#  ('커피', '머신', 225),
#  ('커피', '라이', 3),
#  ('커피', '녹스', 1),
#  ('커피', '현대인', 2),
#  ('커피', '하루', 61),
#  ('커피', '보니', 37),
#  ('커피', '가정', 9),
#  ('커피', '구입', 11),
#  ('커피', '고려', 8),
#  ('커피', '예전', 30),
#  ('커피', '일주일', 8),
#  ('커피', '외출', 18),
#  ('머신', '라이', 1),
#  ('머신', '녹스', 1),
#  ('머신', '현대인', 1),
#  ('머신', '하루', 3),
#  ('머신', '커피', 111),
#  ('머신', '보니', 2),
#  ('머신', '가정', 5),
#  ('머신', '구입', 2),
#  ('머신', '고려', 2),
#  ('머신', '예전', 2),
#  ('머신', '일주일', 2),
#  ('머신', '외출', 4),
#  ('라이', '녹스', 1),
#  ('라이', '현대인', 1),
#  ('라이', '하루', 1),
#  ('라이', '커피', 3),
#  ('라이', '보니', 1),
#  ('라이', '가정', 1),
#  ('라이', '머신', 1),
#  ('라이', '구입', 1),
#  ('라이', '고려', 1),
#  ('라이', '예전', 1),
#  ('라이', '일주일', 1),
#  ('라이', '외출', 1),
#  ('녹스', '현대인', 1),
#  ('녹스', '하루', 1),
#  ('녹스', '커피', 2),
#  ('녹스', '보니', 1),
#  ('녹스', '가정', 1),
#  ('녹스', '머신', 1),
#  ('녹스', '구입', 1),
#  ('녹스', '고려', 1),
#  ('녹스', '예전', 1),
#  ('녹스', '일주일', 1),
#  ('녹스', '외출', 1),
#  ('현대인', '하루', 1),
#  ('현대인', '커피', 3),
#  ('현대인', '보니', 1),
#  ('현대인', '가정', 1),
#  ('현대인', '머신', 1),
#  ('현대인', '구입', 1),
#  ('현대인', '고려', 1),
#  ('현대인', '예전', 1),
#  ('현대인', '일주일', 1),
#  ('현대인', '외출', 1),
#  ('하루', '커피', 59),
#  ('하루', '보니', 2),
#  ('하루', '가정', 1),
#  ('하루', '머신', 4),
#  ('하루', '구입', 1),
#  ('하루', '고려', 1),
#  ('하루', '예전', 2),
#  ('하루', '일주일', 1),
#  ('하루', '외출', 2),
#  ('보니', '가정', 1),
#  ('보니', '커피', 22),
#  ('보니', '머신', 1),
#  ('보니', '구입', 1),
#  ('보니', '고려', 1),
#  ('보니', '예전', 2),
#  ('보니', '일주일', 1),
#  ('보니', '외출', 1),
#  ('구입', '고려', 1),
#  ('구입', '예전', 1),
#  ('구입', '일주일', 1),
#  ('구입', '외출', 1),
#  ('고려', '예전', 1),
#  ('고려', '일주일', 1),
#  ('고려', '외출', 1),
#  ('예전', '일주일', 1),
#  ('예전', '외출', 2),
#  ('일주일', '외출', 1),
#  ('얼마', '친구', 2),
#  ('얼마', '제주도', 3),
#  ('얼마', '유명세', 1),
#  ('얼마', '커피', 34),
#  ('얼마', '맛집', 3),
#  ('얼마', '신선', 1),
#  ('얼마', '재료', 1),
#  ('얼마', '메뉴', 1),
#  ('얼마', '시작', 2),
#  ('얼마', '각종', 1),
#  ('얼마', '디저트', 1),
#  ('얼마', '음료', 2),
#  ('얼마', '다양', 1),
#  ('친구', '제주도', 3),
#  ('친구', '유명세', 1),
#  ('친구', '맛집', 6),
#  ('친구', '신선', 1),
#  ('친구', '재료', 1),
#  ('친구', '메뉴', 2),
#  ('친구', '시작', 1),
#  ('친구', '각종', 1),
#  ('친구', '디저트', 2),
#  ('친구', '음료', 2),
#  ('친구', '다양', 1),
#  ('제주도', '유명세', 1),
#  ('제주도', '커피', 24),
#  ('제주도', '맛집', 5),
#  ('제주도', '신선', 2),
#  ('제주도', '재료', 2),
#  ('제주도', '메뉴', 4),
#  ('제주도', '시작', 3),
#  ('제주도', '각종', 3),
#  ('제주도', '디저트', 3),
#  ('제주도', '음료', 3),
#  ('제주도', '다양', 3),
#  ('유명세', '제주도', 2),
#  ('유명세', '커피', 3),
#  ('유명세', '맛집', 2),
#  ('유명세', '신선', 1),
#  ('유명세', '재료', 1),
#  ('유명세', '메뉴', 1),
#  ('유명세', '시작', 1),
#  ('유명세', '각종', 1),
#  ('유명세', '디저트', 1),
#  ('유명세', '음료', 1),
#  ('유명세', '다양', 1),
#  ('커피', '신선', 6),
#  ('커피', '재료', 11),
#  ('커피', '제주도', 11),
#  ('커피', '메뉴', 90),
#  ('커피', '시작', 38),
#  ('커피', '각종', 7),
#  ('커피', '음료', 59),
#  ('커피', '다양', 55),
#  ('맛집', '신선', 1),
#  ('맛집', '재료', 1),
#  ('맛집', '제주도', 2),
#  ('맛집', '메뉴', 7),
#  ('맛집', '시작', 2),
#  ('맛집', '각종', 2),
#  ('맛집', '디저트', 4),
#  ('맛집', '음료', 4),
#  ('맛집', '다양', 4),
#  ('신선', '재료', 1),
#  ('신선', '제주도', 1),
#  ('신선', '커피', 7),
#  ('신선', '맛집', 1),
#  ('신선', '메뉴', 1),
#  ('신선', '시작', 1),
#  ('신선', '각종', 1),
#  ('신선', '디저트', 1),
#  ('신선', '음료', 1),
#  ('신선', '다양', 2),
#  ('재료', '제주도', 1),
#  ('재료', '커피', 8),
#  ('재료', '맛집', 1),
#  ('재료', '메뉴', 1),
#  ('재료', '시작', 1),
#  ('재료', '각종', 1),
#  ('재료', '디저트', 1),
#  ('재료', '음료', 1),
#  ('재료', '다양', 1),
#  ('메뉴', '시작', 1),
#  ('메뉴', '각종', 1),
#  ('메뉴', '디저트', 7),
#  ('메뉴', '음료', 5),
#  ('메뉴', '다양', 5),
#  ('시작', '각종', 1),
#  ('시작', '디저트', 1),
#  ('시작', '음료', 2),
#  ('시작', '다양', 1),
#  ('각종', '디저트', 1),
#  ('각종', '음료', 2),
#  ('각종', '다양', 1),
#  ('디저트', '음료', 7),
#  ('디저트', '다양', 3),
#  ('음료', '다양', 2),
#  ('부산', '달맞이고개', 1),
#  ('부산', '라이프', 4),
#  ('부산', '니블', 1),
#  ('부산', '로그', 1),
#  ('부산', '안녕하세요', 1),
#  ('부산', '오랜만', 2),
#  ('부산', '아인', 2),
#  ('부산', '키노', 2),
#  ('부산', '가구', 1),
#  ('부산', '중심', 1),
#  ('부산', '여백', 1),
#  ('부산', '컬러', 1),
#  ('부산', '구성', 1),
#  ('부산', '요소', 1),
#  ('달맞이고개', '카페', 1),
#  ('달맞이고개', '라이프', 2),
#  ('달맞이고개', '커피', 3),
#  ('달맞이고개', '사진', 1),
#  ('달맞이고개', '니블', 1),
#  ('달맞이고개', '로그', 1),
#  ('달맞이고개', '안녕하세요', 1),
#  ('달맞이고개', '오랜만', 1),
#  ('달맞이고개', '아인', 1),
#  ('달맞이고개', '키노', 1),
#  ('달맞이고개', '가구', 1),
#  ('달맞이고개', '중심', 1),
#  ('달맞이고개', '여백', 1),
#  ('달맞이고개', '컬러', 1),
#  ('달맞이고개', '구성', 1),
#  ('달맞이고개', '요소', 1),
#  ('카페', '라이프', 3),
#  ('카페', '니블', 1),
#  ('카페', '로그', 1),
#  ('카페', '안녕하세요', 19),
#  ('카페', '오랜만', 7),
#  ('카페', '아인', 1),
#  ('카페', '키노', 1),
#  ('카페', '가구', 1),
#  ('카페', '중심', 1),
#  ('카페', '여백', 1),
#  ('카페', '컬러', 1),
#  ('카페', '구성', 2),
#  ('카페', '요소', 1),
#  ('라이프', '커피', 14),
#  ('라이프', '사진', 1),
#  ('라이프', '니블', 1),
#  ('라이프', '로그', 1),
#  ('라이프', '안녕하세요', 1),
#  ('라이프', '오랜만', 1),
#  ('라이프', '아인', 2),
#  ('라이프', '키노', 2),
#  ('라이프', '가구', 2),
#  ('라이프', '중심', 2),
#  ('라이프', '여백', 2),
#  ('라이프', '컬러', 2),
#  ('라이프', '구성', 2),
#  ('라이프', '요소', 2),
#  ('커피', '니블', 2),
#  ('커피', '로그', 3),
#  ('커피', '안녕하세요', 46),
#  ('커피', '라이프', 3),
#  ('커피', '아인', 2),
#  ('커피', '키노', 2),
#  ('커피', '가구', 4),
#  ('커피', '중심', 5),
#  ('커피', '여백', 3),
#  ('커피', '컬러', 7),
#  ('커피', '구성', 18),
#  ('커피', '요소', 4),
#  ('사진', '니블', 1),
#  ('사진', '로그', 1),
#  ('사진', '안녕하세요', 4),
#  ('사진', '오랜만', 1),
#  ('사진', '라이프', 1),
#  ('사진', '커피', 57),
#  ('사진', '아인', 1),
#  ('사진', '키노', 1),
#  ('사진', '가구', 1),
#  ('사진', '중심', 1),
#  ('사진', '여백', 1),
#  ('사진', '컬러', 1),
#  ('사진', '구성', 1),
#  ('사진', '요소', 1),
#  ('니블', '로그', 1),
#  ('니블', '안녕하세요', 1),
#  ('니블', '오랜만', 1),
#  ('니블', '라이프', 1),
#  ('니블', '커피', 5),
#  ('니블', '아인', 1),
#  ('니블', '키노', 1),
#  ('니블', '가구', 1),
#  ('니블', '중심', 1),
#  ('니블', '여백', 1),
#  ('니블', '컬러', 1),
#  ('니블', '구성', 1),
#  ('니블', '요소', 1),
#  ('로그', '안녕하세요', 1),
#  ('로그', '오랜만', 1),
#  ('로그', '라이프', 1),
#  ('로그', '커피', 6),
#  ('로그', '아인', 1),
#  ('로그', '키노', 1),
#  ('로그', '가구', 1),
#  ('로그', '중심', 1),
#  ('로그', '여백', 1),
#  ('로그', '컬러', 1),
#  ('로그', '구성', 1),
#  ('로그', '요소', 1),
#  ('안녕하세요', '오랜만', 2),
#  ('안녕하세요', '라이프', 1),
#  ('안녕하세요', '커피', 83),
#  ('안녕하세요', '아인', 1),
#  ('안녕하세요', '키노', 1),
#  ('안녕하세요', '가구', 1),
#  ('안녕하세요', '중심', 1),
#  ('안녕하세요', '여백', 1),
#  ('안녕하세요', '컬러', 1),
#  ('안녕하세요', '구성', 1),
#  ('안녕하세요', '요소', 1),
#  ('오랜만', '라이프', 1),
#  ('오랜만', '아인', 1),
#  ('오랜만', '키노', 1),
#  ('오랜만', '가구', 1),
#  ('오랜만', '중심', 1),
#  ('오랜만', '여백', 1),
#  ('오랜만', '컬러', 1),
#  ('오랜만', '구성', 1),
#  ('오랜만', '요소', 1),
#  ('아인', '키노', 2),
#  ('아인', '가구', 1),
#  ('아인', '중심', 1),
#  ('아인', '커피', 3),
#  ('아인', '여백', 1),
#  ('아인', '컬러', 1),
#  ('아인', '구성', 1),
#  ('아인', '요소', 1),
#  ('키노', '가구', 1),
#  ('키노', '중심', 1),
#  ('키노', '커피', 3),
#  ('키노', '여백', 1),
#  ('키노', '컬러', 1),
#  ('키노', '구성', 1),
#  ('키노', '요소', 1),
#  ('가구', '중심', 1),
#  ('가구', '커피', 3),
#  ('가구', '여백', 1),
#  ('가구', '컬러', 1),
#  ('가구', '구성', 1),
#  ('가구', '요소', 1),
#  ('중심', '커피', 1),
#  ('중심', '여백', 1),
#  ('중심', '컬러', 1),
#  ('중심', '구성', 1),
#  ('중심', '요소', 1),
#  ('여백', '컬러', 1),
#  ('여백', '구성', 1),
#  ('여백', '요소', 1),
#  ('컬러', '구성', 2),
#  ('컬러', '요소', 1),
#  ('구성', '요소', 1),
#  ('섬유', '유연', 1),
#  ('섬유', '구매', 1),
#  ('섬유', '제가', 1),
#  ('섬유', '평소', 1),
#  ('섬유', '케냐', 1),
#  ('섬유', '원두', 1),
#  ('섬유', '커피', 2),
#  ('섬유', '판매', 1),
#  ('섬유', '저렴', 1),
#  ('섬유', '가격', 1),
#  ('섬유', '추천', 1),
#  ('섬유', '백인', 1),
#  ('섬유', '상자', 1),
#  ('유연', '구매', 1),
#  ('유연', '제가', 1),
#  ('유연', '평소', 1),
#  ('유연', '케냐', 1),
#  ('유연', '원두', 1),
#  ('유연', '커피', 3),
#  ('유연', '판매', 1),
#  ('유연', '저렴', 1),
#  ('유연', '가격', 1),
#  ('유연', '추천', 1),
#  ('유연', '백인', 1),
#  ('유연', '상자', 1),
#  ('구매', '제가', 1),
#  ('구매', '평소', 1),
#  ('구매', '케냐', 1),
#  ('구매', '원두', 5),
#  ('구매', '커피', 22),
#  ('구매', '판매', 1),
#  ('구매', '저렴', 1),
#  ('구매', '가격', 2),
#  ('구매', '추천', 6),
#  ('구매', '백인', 1),
#  ('구매', '상자', 1),
#  ('제가', '평소', 1),
#  ('제가', '케냐', 1),
#  ('제가', '원두', 5),
#  ('제가', '커피', 46),
#  ('제가', '판매', 1),
#  ('제가', '저렴', 1),
#  ('제가', '가격', 1),
#  ('제가', '추천', 2),
#  ('제가', '백인', 1),
#  ('제가', '상자', 1),
#  ('평소', '케냐', 1),
#  ('평소', '원두', 2),
#  ('평소', '커피', 27),
#  ('평소', '판매', 1),
#  ('평소', '저렴', 1),
#  ('평소', '가격', 1),
#  ('평소', '추천', 2),
#  ('평소', '백인', 1),
#  ('평소', '상자', 1),
#  ('케냐', '원두', 2),
#  ('케냐', '커피', 6),
#  ('케냐', '판매', 1),
#  ('케냐', '저렴', 1),
#  ('케냐', '가격', 1),
#  ('케냐', '추천', 1),
#  ('케냐', '백인', 1),
#  ('케냐', '상자', 1),
#  ('원두', '커피', 98),
#  ('원두', '판매', 3),
#  ('원두', '저렴', 3),
#  ('원두', '가격', 5),
#  ('원두', '추천', 12),
#  ('원두', '백인', 1),
#  ('원두', '상자', 2),
#  ('커피', '판매', 39),
#  ('커피', '저렴', 23),
#  ('커피', '가격', 44),
#  ('커피', '추천', 72),
#  ('커피', '백인', 2),
#  ('커피', '상자', 6),
#  ('판매', '저렴', 1),
#  ('판매', '가격', 1),
#  ('판매', '추천', 2),
#  ('판매', '커피', 7),
#  ('판매', '백인', 1),
#  ('판매', '상자', 1),
#  ('저렴', '가격', 2),
#  ('저렴', '추천', 1),
#  ('저렴', '커피', 12),
#  ('저렴', '백인', 1),
#  ('저렴', '상자', 1),
#  ('가격', '추천', 1),
#  ('가격', '커피', 19),
#  ('가격', '백인', 1),
#  ('가격', '상자', 1),
#  ('추천', '커피', 77),
#  ('추천', '백인', 1),
#  ('추천', '상자', 1),
#  ('백인', '상자', 1),
#  ('커피', '요즘', 92),
#  ('커피', '주변', 19),
#  ('커피', '인구', 4),
#  ('요즘', '주변', 1),
#  ('요즘', '카페', 23),
#  ('요즘', '다양', 1),
#  ('요즘', '커피', 84),
#  ('요즘', '음료', 2),
#  ('요즘', '인구', 1),
#  ('주변', '카페', 3),
#  ('주변', '다양', 1),
#  ('주변', '커피', 9),
#  ('주변', '음료', 1),
#  ('주변', '인구', 1),
#  ('카페', '다양', 11),
#  ('카페', '음료', 20),
#  ('카페', '인구', 3),
#  ('다양', '커피', 37),
#  ('다양', '음료', 4),
#  ('다양', '인구', 1),
#  ('음료', '커피', 28),
#  ('음료', '인구', 1),
#  ('인구', '커피', 1),
#  ('일산', '성비', 1),
#  ('일산', '포트', 3),
#  ('일산', '캔커피', 3),
#  ('일산', '폭탄', 1),
#  ('일산', '카스', 1),
#  ('일산', '테라', 1),
#  ('일산', '페스', 4),
#  ('일산', '오픈', 3),
#  ('일산', '타점', 2),
#  ('일산', '이날', 2),
#  ('일산', '다음날', 2),
#  ('일산', '스페셜', 2),
#  ('일산', '커피', 18),
#  ('성비', '포트', 2),
#  ('성비', '캔커피', 2),
#  ('성비', '폭탄', 1),
#  ('성비', '카스', 1),
#  ('성비', '테라', 1),
#  ('성비', '일산', 1),
#  ('성비', '페스', 2),
#  ('성비', '오픈', 1),
#  ('성비', '타점', 1),
#  ('성비', '이날', 1),
#  ('성비', '다음날', 1),
#  ('성비', '스페셜', 1),
#  ('성비', '커피', 17),
#  ('포트', '캔커피', 3),
#  ('포트', '폭탄', 1),
#  ('포트', '카스', 1),
#  ('포트', '테라', 1),
#  ('포트', '일산', 1),
#  ('포트', '페스', 3),
#  ('포트', '오픈', 1),
#  ('포트', '타점', 2),
#  ('포트', '이날', 2),
#  ('포트', '다음날', 2),
#  ('포트', '스페셜', 2),
#  ('포트', '커피', 23),
#  ('캔커피', '폭탄', 1),
#  ('캔커피', '카스', 1),
#  ('캔커피', '테라', 1),
#  ('캔커피', '일산', 1),
#  ('캔커피', '페스', 3),
#  ('캔커피', '오픈', 1),
#  ('캔커피', '포트', 1),
#  ('캔커피', '타점', 2),
#  ('캔커피', '이날', 2),
#  ('캔커피', '다음날', 2),
#  ('캔커피', '스페셜', 2),
#  ('캔커피', '커피', 3),
#  ('폭탄', '카스', 1),
#  ('폭탄', '테라', 1),
#  ('폭탄', '일산', 1),
#  ('폭탄', '페스', 2),
#  ('폭탄', '오픈', 1),
#  ('폭탄', '포트', 1),
#  ('폭탄', '캔커피', 1),
#  ('폭탄', '타점', 1),
#  ('폭탄', '이날', 1),
#  ('폭탄', '다음날', 1),
#  ('폭탄', '스페셜', 1),
#  ('폭탄', '커피', 1),
#  ('카스', '테라', 1),
#  ('카스', '일산', 1),
#  ('카스', '페스', 2),
#  ('카스', '오픈', 1),
#  ('카스', '포트', 1),
#  ('카스', '캔커피', 1),
#  ('카스', '타점', 1),
#  ('카스', '이날', 1),
#  ('카스', '다음날', 1),
#  ('카스', '스페셜', 1),
#  ('카스', '커피', 1),
#  ('테라', '일산', 1),
#  ('테라', '페스', 2),
#  ('테라', '오픈', 1),
#  ('테라', '포트', 1),
#  ('테라', '캔커피', 1),
#  ('테라', '타점', 1),
#  ('테라', '이날', 1),
#  ('테라', '다음날', 1),
#  ('테라', '스페셜', 1),
#  ('테라', '커피', 1),
#  ('페스', '오픈', 1),
#  ('페스', '포트', 1),
#  ('페스', '캔커피', 1),
#  ('페스', '타점', 2),
#  ('페스', '이날', 2),
#  ('페스', '다음날', 2),
#  ('페스', '스페셜', 2),
#  ('페스', '커피', 4),
#  ('오픈', '포트', 1),
#  ('오픈', '캔커피', 1),
#  ('오픈', '페스', 1),
#  ('오픈', '타점', 1),
#  ('오픈', '이날', 1),
#  ('오픈', '다음날', 1),
#  ('오픈', '스페셜', 1),
#  ('오픈', '커피', 37),
#  ('타점', '이날', 1),
#  ('타점', '다음날', 1),
#  ('타점', '스페셜', 1),
#  ('타점', '커피', 1),
#  ('이날', '다음날', 1),
#  ('이날', '스페셜', 3),
#  ('이날', '커피', 17),
#  ('다음날', '스페셜', 1),
#  ('다음날', '커피', 2),
#  ('스페셜', '커피', 27),
#  ('카페', '캡슐', 10),
#  ('카페', '에스프레소', 9),
#  ('카페', '추출', 2),
#  ('카페', '머신', 33),
#  ('카페', '사용', 16),
#  ('카페', '조사', 1),
#  ('카페', '대부분', 3),
#  ('카페', '비닐', 1),
#  ('카페', '플라스틱', 2),
#  ('카페', '소재', 1),
#  ('커피', '캡슐', 57),
#  ('커피', '에스프레소', 36),
#  ('커피', '추출', 25),
#  ('커피', '사용', 72),
#  ('커피', '조사', 5),
#  ('커피', '대부분', 9),
#  ('커피', '비닐', 4),
#  ('커피', '플라스틱', 7),
#  ('커피', '소재', 5),
#  ('캡슐', '에스프레소', 1),
#  ('캡슐', '추출', 2),
#  ('캡슐', '커피', 65),
#  ('캡슐', '머신', 18),
#  ('캡슐', '사용', 6),
#  ('캡슐', '조사', 1),
#  ('캡슐', '대부분', 1),
#  ('캡슐', '비닐', 2),
#  ('캡슐', '플라스틱', 2),
#  ('캡슐', '소재', 2),
#  ('에스프레소', '추출', 5),
#  ('에스프레소', '커피', 36),
#  ('에스프레소', '머신', 13),
#  ('에스프레소', '사용', 4),
#  ('에스프레소', '조사', 1),
#  ('에스프레소', '대부분', 1),
#  ('에스프레소', '캡슐', 3),
#  ('에스프레소', '비닐', 1),
#  ('에스프레소', '플라스틱', 1),
#  ('에스프레소', '소재', 1),
#  ('추출', '커피', 19),
#  ('추출', '머신', 3),
#  ('추출', '사용', 1),
#  ('추출', '조사', 1),
#  ('추출', '대부분', 1),
#  ('추출', '캡슐', 1),
#  ('추출', '비닐', 1),
#  ('추출', '플라스틱', 1),
#  ('추출', '소재', 1),
#  ('머신', '사용', 24),
#  ('머신', '조사', 1),
#  ('머신', '대부분', 1),
#  ('머신', '캡슐', 11),
#  ('머신', '비닐', 1),
#  ('머신', '플라스틱', 1),
#  ('머신', '소재', 1),
#  ('사용', '조사', 1),
#  ('사용', '대부분', 1),
#  ('사용', '커피', 37),
#  ('사용', '캡슐', 3),
#  ('사용', '비닐', 1),
#  ('사용', '플라스틱', 1),
#  ('사용', '소재', 1),
#  ('조사', '대부분', 1),
#  ('조사', '커피', 6),
#  ('조사', '캡슐', 1),
#  ('조사', '비닐', 1),
#  ('조사', '플라스틱', 1),
#  ('조사', '소재', 1),
#  ('대부분', '커피', 6),
#  ('대부분', '캡슐', 1),
#  ('대부분', '비닐', 1),
#  ('대부분', '플라스틱', 1),
#  ('대부분', '소재', 1),
#  ('비닐', '커피', 1),
#  ('비닐', '플라스틱', 1),
#  ('비닐', '소재', 1),
#  ('플라스틱', '소재', 1),
#  ('제가', '분유', 2),
#  ('제가', '전기', 2),
#  ('제가', '포트', 3),
#  ('제가', '이용', 3),
#  ('제가', '사실', 2),
#  ('제가', '생각', 1),
#  ('분유', '전기', 2),
#  ('분유', '커피', 2),
#  ('분유', '포트', 2),
#  ('분유', '이용', 2),
#  ('분유', '사실', 1),
#  ('분유', '생각', 2),
#  ('전기', '커피', 6),
#  ...]

# %%
def count_key(t):
    return t[2]

graphdata.sort(key=count_key, reverse=True)
graphdata
# Out:
# [('카페', '커피', 678),
#  ('커피', '카페', 543),
#  ('커피', '머신', 225),
#  ('커피', '원두', 121),
#  ('머신', '커피', 111),
#  ('오늘', '커피', 108),
#  ('커피', '주문', 106),
#  ('원두', '커피', 98),
#  ('커피', '요즘', 92),
#  ('커피', '메뉴', 90),
#  ('아침', '커피', 88),
#  ('요즘', '커피', 84),
#  ('위치', '커피', 84),
#  ('안녕하세요', '커피', 83),
#  ('커피', '위치', 81),
#  ('커피', '한잔', 80),
#  ('커피', '방문', 78),
#  ('추천', '커피', 77),
#  ('선물', '커피', 74),
#  ('더치', '커피', 74),
#  ('커피', '추천', 72),
#  ('커피', '사용', 72),
#  ('커피', '시간', 72),
#  ('강릉', '커피', 68),
#  ('캡슐', '커피', 65),
#  ('커피', '사람', 65),
#  ('커피', '느낌', 64),
#  ('커피', '생각', 63),
#  ('시간', '커피', 63),
#  ('맛집', '커피', 62),
#  ('커피', '하루', 61),
#  ('이번', '커피', 60),
#  ('커피', '정도', 60),
#  ('한잔', '커피', 60),
#  ('하루', '커피', 59),
#  ('커피', '음료', 59),
#  ('카페', '위치', 59),
#  ('근처', '커피', 58),
#  ('커피', '카페인', 58),
#  ('소개', '커피', 58),
#  ('커피', '사진', 57),
#  ('사진', '커피', 57),
#  ('커피', '캡슐', 57),
#  ('커피', '선물', 57),
#  ('커피', '오늘', 56),
#  ('커피', '다양', 55),
#  ('커피', '아메리카노', 55),
#  ('커피', '아침', 55),
#  ('커피', '디저트', 54),
#  ('메뉴', '커피', 54),
#  ('아보카도', '커피', 53),
#  ('커피', '제가', 52),
#  ('아이스', '커피', 52),
#  ('커피', '이번', 51),
#  ('방문', '커피', 51),
#  ('커피', '건물', 51),
#  ('편의점', '커피', 51),
#  ('커피', '소개', 51),
#  ('커피', '맛집', 50),
#  ('믹스', '커피', 49),
#  ('핸드', '커피', 48),
#  ('커피', '아이스', 48),
#  ('카페인', '커피', 47),
#  ('커피', '강릉', 46),
#  ('커피', '분위기', 46),
#  ('커피', '안녕하세요', 46),
#  ('제가', '커피', 46),
#  ('시작', '커피', 46),
#  ('주말', '커피', 46),
#  ('커피', '주차', 46),
#  ('커피', '매장', 45),
#  ('커피', '세트', 45),
#  ('커피', '근처', 45),
#  ('커피', '가격', 44),
#  ('커피', '자리', 44),
#  ('커피', '더치', 44),
#  ('커피', '라고', 43),
#  ('대구', '커피', 43),
#  ('커피', '오픈', 43),
#  ('커피', '스팅', 43),
#  ('네스프레소', '커피', 43),
#  ('디저트', '커피', 41),
#  ('사람', '커피', 41),
#  ('근처', '카페', 41),
#  ('커피', '유명', 41),
#  ('커피', '여행', 41),
#  ('커피', '입구', 40),
#  ('위치', '카페', 40),
#  ('유명', '커피', 40),
#  ('여행', '커피', 40),
#  ('커피', '구매', 40),
#  ('커피', '판매', 39),
#  ('주문', '커피', 39),
#  ('커피', '시작', 38),
#  ('세트', '커피', 38),
#  ('커피', '편의점', 38),
#  ('커피', '보니', 37),
#  ('다양', '커피', 37),
#  ('오픈', '커피', 37),
#  ('사용', '커피', 37),
#  ('스팅', '커피', 37),
#  ('커피', '처음', 37),
#  ('커피', '에스프레소', 36),
#  ('에스프레소', '커피', 36),
#  ('커피', '공간', 36),
#  ('커피', '종류', 36),
#  ('커피', '거리', 36),
#  ('커피', '로스팅', 36),
#  ('생각', '커피', 35),
#  ('안녕하세요', '카페', 35),
#  ('커피', '가능', 35),
#  ('커피', '제품', 35),
#  ('친구', '커피', 34),
#  ('얼마', '커피', 34),
#  ('커피', '궁금', 34),
#  ('카페', '추천', 34),
#  ('커피', '마시기', 34),
#  ('서울', '커피', 34),
#  ('카페', '머신', 33),
#  ('카페', '원두', 33),
#  ('커피', '회사', 33),
#  ('아메리카노', '커피', 33),
#  ('커피', '이름', 32),
#  ('오늘', '카페', 32),
#  ('커피', '아보카도', 32),
#  ('정도', '커피', 32),
#  ('카페', '방문', 32),
#  ('동네', '커피', 32),
#  ('커피', '대신', 32),
#  ('신상', '커피', 32),
#  ('커피', '핸드', 31),
#  ('따뜻', '커피', 31),
#  ('메가', '커피', 31),
#  ('커피', '예전', 30),
#  ('날씨', '커피', 30),
#  ('선물', '세트', 30),
#  ('시원', '커피', 30),
#  ('커피', '사장', 30),
#  ('신상', '카페', 30),
#  ('커피', '오랜만', 29),
#  ('커피', '이제', 29),
#  ('감성', '커피', 29),
#  ('카페', '건물', 29),
#  ('커피', '간편', 29),
#  ('커피', '외관', 29),
#  ('안목', '커피', 29),
#  ('커피', '내부', 29),
#  ('커피', '취향', 29),
#  ('음료', '커피', 28),
#  ('커피', '감성', 28),
#  ('커피', '영업시간', 28),
#  ('카페', '시간', 28),
#  ('여유', '커피', 28),
#  ('커피', '따뜻', 28),
#  ('강릉', '안목', 28),
#  ('커피', '후기', 28),
#  ('커피', '주소', 28),
#  ('평소', '커피', 27),
#  ('스페셜', '커피', 27),
#  ('커피', '주말', 27),
#  ('맛집', '카페', 27),
#  ('카페', '요즘', 27),
#  ('카멜', '커피', 27),
#  ('하프', '커피', 27),
#  ('커피', '스페셜', 27),
#  ('카페', '디저트', 26),
#  ('분위기', '커피', 26),
#  ('커피', '사랑', 26),
#  ('커피', '바리스타', 26),
#  ('커피', '믹스', 26),
#  ('커피', '브랜드', 26),
#  ('부산', '커피', 25),
#  ('커피', '추출', 25),
#  ('느낌', '커피', 25),
#  ('커피', '남편', 25),
#  ('커피', '그라인더', 25),
#  ('커피', '크림', 25),
#  ('처음', '커피', 25),
#  ('로스팅', '커피', 25),
#  ('커피', '기본', 25),
#  ('커피', '우유', 25),
#  ('우유', '커피', 25),
#  ('세종', '카페', 25),
#  ('커피', '친구', 24),
#  ('분위기', '카페', 24),
#  ('제주도', '커피', 24),
#  ('머신', '사용', 24),
#  ('커피', '사실', 24),
#  ('커피', '제일', 24),
#  ('카페', '느낌', 24),
#  ('커피', '여유', 24),
#  ('커피', '식사', 24),
#  ('커피', '준비', 24),
#  ('주차', '커피', 24),
#  ('커피', '평일', 24),
#  ('커피', '검색', 24),
#  ('카페', '주문', 24),
#  ('카페', '입구', 24),
#  ('일리', '커피', 24),
#  ('커피', '아아', 24),
#  ('초당', '커피', 24),
#  ('커피', '저렴', 23),
#  ('요즘', '카페', 23),
#  ('포트', '커피', 23),
#  ('카페', '근처', 23),
#  ('거리', '커피', 23),
#  ('커피', '블로그', 23),
#  ('해변', '커피', 23),
#  ('준비', '커피', 23),
#  ('방문', '카페', 23),
#  ('후기', '커피', 23),
#  ('이야기', '커피', 23),
#  ('보니', '커피', 22),
#  ('구매', '커피', 22),
#  ('매장', '커피', 22),
#  ('간편', '커피', 22),
#  ('카페', '외관', 22),
#  ('공간', '커피', 22),
#  ('커피', '주차장', 22),
#  ('커피', '바다', 22),
#  ('쿠키', '커피', 22),
#  ('건물', '커피', 22),
#  ('행복', '커피', 22),
#  ('오후', '커피', 22),
#  ('커피', '행복', 22),
#  ('커피', '신상', 22),
#  ('강릉', '카페', 21),
#  ('카페', '분위기', 21),
#  ('커피', '이용', 21),
#  ('사실', '커피', 21),
#  ('커피', '대구', 21),
#  ('저녁', '커피', 21),
#  ('강릉', '해변', 21),
#  ('커피', '안목', 21),
#  ('크림', '커피', 21),
#  ('커피', '테이크아웃', 21),
#  ('커피', '기분', 21),
#  ('머신', '카페', 21),
#  ('라운드', '커피', 20),
#  ('커피', '아이', 20),
#  ('오랜만', '커피', 20),
#  ('카페', '음료', 20),
#  ('카페', '공간', 20),
#  ('커피', '가을', 20),
#  ('커피', '얼마', 20),
#  ('남편', '커피', 20),
#  ('바람', '커피', 20),
#  ('카페', '자리', 20),
#  ('커피', '동네', 20),
#  ('블로그', '커피', 20),
#  ('커피', '이야기', 20),
#  ('안목', '해변', 20),
#  ('오늘', '소개', 20),
#  ('커피', '테이블', 20),
#  ('커피', '가루', 20),
#  ('포즈', '커피', 20),
#  ('카페', '소개', 20),
#  ('대전', '커피', 20),
#  ('커피', '부산', 19),
#  ('카페', '안녕하세요', 19),
#  ('가격', '커피', 19),
#  ('커피', '주변', 19),
#  ('추출', '커피', 19),
#  ('연남동', '커피', 19),
#  ('커피', '여름', 19),
#  ('자동', '커피', 19),
#  ('커피', '공장', 19),
#  ('용산', '카페', 19),
#  ('커피', '두도', 19),
#  ('커피', '바닐라', 19),
#  ('가능', '커피', 19),
#  ('기분', '커피', 19),
#  ('네스프레소', '캡슐', 19),
#  ('취향', '커피', 19),
#  ('카페', '메뉴', 19),
#  ('커피', '습관', 19),
#  ('커피', '원액', 19),
#  ('커피', '외출', 18),
#  ('커피', '구성', 18),
#  ('일산', '커피', 18),
#  ('캡슐', '머신', 18),
#  ('여름', '커피', 18),
#  ('입구', '커피', 18),
#  ('추천', '카페', 18),
#  ('커피', '저녁', 18),
#  ('개인', '커피', 18),
#  ('카페', '사람', 18),
#  ('감성', '카페', 18),
#  ('카페', '주차', 18),
#  ('점심', '커피', 18),
#  ('커피', '해변', 18),
#  ('커피', '케이크', 18),
#  ('느낌', '카페', 18),
#  ('카페', '검색', 18),
#  ('커피', '네스프레소', 18),
#  ('브런치', '커피', 18),
#  ('초당', '버거', 18),
#  ('피츠커피', '커피', 18),
#  ('카페', '이번', 17),
#  ('카페', '사진', 17),
#  ('성비', '커피', 17),
#  ('이날', '커피', 17),
#  ('자리', '커피', 17),
#  ('자동', '머신', 17),
#  ('세븐', '아보카도', 17),
#  ('커피', '본점', 17),
#  ('커피', '박물관', 17),
#  ('대구', '카페', 17),
#  ('카페', '가능', 17),
#  ('커피', '원래', 17),
#  ('한국', '커피', 17),
#  ('커피', '날씨', 17),
#  ('커피', '한과', 17),
#  ('커피', '쿠키', 17),
#  ('커피', '산미', 17),
#  ('커피', '베이커리', 17),
#  ('커피', '진심', 17),
#  ('커피', '이유', 17),
#  ('루프', '커피', 17),
#  ('일리', '머신', 17),
#  ('커피', '일리', 17),
#  ('커피', '코로나', 17),
#  ('커피', '파운드', 17),
#  ('세종', '커피', 17),
#  ('프리미엄', '커피', 17),
#  ('플라워', '커피', 17),
#  ('카페', '이름', 16),
#  ('가정', '커피', 16),
#  ('카페', '사용', 16),
#  ('시간', '카페', 16),
#  ('카페', '오늘', 16),
#  ('커피', '자동', 16),
#  ('식사', '커피', 16),
#  ('캠핑', '커피', 16),
#  ('커피', '고민', 16),
#  ('강릉', '거리', 16),
#  ('커피', '오후', 16),
#  ('추석', '선물', 16),
#  ('검색', '커피', 16),
#  ('커피', '최근', 16),
#  ('이름', '커피', 16),
#  ('커피', '오피', 16),
#  ('카페', '처음', 16),
#  ('커피', '인테리어', 16),
#  ('커피', '서울', 16),
#  ('한잔', '카페', 16),
#  ('춘천', '커피', 16),
#  ('호환', '커피', 16),
#  ('카페', '아메리카노', 16),
#  ('커피', '관련', 16),
#  ('커피', '초당', 16),
#  ('브런치', '카페', 16),
#  ('커피', '플라워', 16),
#  ('오피', '커피', 16),
#  ('브랜드', '커피', 16),
#  ('커피', '아이스크림', 16),
#  ('사용', '머신', 16),
#  ('원두', '카페', 15),
#  ('커피', '발견', 15),
#  ('가을', '커피', 15),
#  ('세븐', '커피', 15),
#  ('디저트', '카페', 15),
#  ('안녕하세요', '오늘', 15),
#  ('리단', '카페', 15),
#  ('리단', '커피', 15),
#  ('커피', '점심', 15),
#  ('카페', '보니', 15),
#  ('제품', '커피', 15),
#  ('쿠키', '선물', 15),
#  ('쿠키', '세트', 15),
#  ('커피', '추석', 15),
#  ('세트', '선물', 15),
#  ('예전', '커피', 15),
#  ('커피', '출시', 15),
#  ('스타벅스', '커피', 15),
#  ('카페', '평일', 15),
#  ('커피', '혼자', 15),
#  ('카페', '루프', 15),
#  ('커피', '선택', 15),
#  ('커피', '구경', 15),
#  ('모카', '커피', 15),
#  ('커피', '모습', 15),
#  ('커피', '인기', 15),
#  ('이제', '커피', 15),
#  ('기본', '커피', 15),
#  ('오전', '커피', 15),
#  ('식당', '커피', 15),
#  ('아크', '카페', 15),
#  ('커피', '체리', 15),
#  ('편의점', '플라워', 15),
#  ('피니시', '커피', 15),
#  ('커피', '운영', 15),
#  ('찰떡', '초당', 15),
#  ('현대', '커피', 15),
#  ('커피', '지인', 15),
#  ('가정', '머신', 14),
#  ('라이프', '커피', 14),
#  ('커피', '포트', 14),
#  ('테라로사', '커피', 14),
#  ('바다', '커피', 14),
#  ('카페', '영업시간', 14),
#  ('커피', '모카', 14),
#  ('카페', '주말', 14),
#  ('카페', '정도', 14),
#  ('주말', '카페', 14),
#  ('커피', '과일', 14),
#  ('마음', '커피', 14),
#  ('사랑', '커피', 14),
#  ('아이스', '아메리카노', 14),
#  ('커피', '개인', 14),
#  ('카페', '감성', 14),
#  ('커피', '블랙', 14),
#  ('커피', '리단', 14),
#  ('프롬', '커피', 14),
#  ('카페', '거리', 14),
#  ('커피', '야외', 14),
#  ('대신', '커피', 14),
#  ('커피', '그니', 14),
#  ('사부', '쿠키', 14),
#  ('쿠키', '고어', 14),
#  ('쿠키', '라운드', 14),
#  ('고어', '커피', 14),
#  ('그중', '커피', 14),
#  ('주문', '카페', 14),
#  ('커피', '골목', 14),
#  ('커피', '맥심', 14),
#  ('편의점', '오피', 14),
#  ('커피', '전문점', 14),
#  ('커피', '이다', 14),
#  ('일요일', '커피', 14),
#  ('산책', '커피', 14),
#  ('루프', '카페', 14),
#  ('신세계백화점', '커피', 14),
#  ('커피', '하프', 14),
#  ('커피', '전문', 14),
#  ('간판', '커피', 14),
#  ('카페', '강릉', 14),
#  ('한옥', '카페', 14),
#  ('한옥', '커피', 14),
#  ('커피', '필요', 14),
#  ('커피', '세종', 14),
#  ('커피', '용품', 14),
#  ('커피', '오전', 14),
#  ('카페', '세종', 14),
#  ('카페', '더치', 14),
#  ('커피', '출근', 14),
#  ('커피', '성비', 14),
#  ('심플', '커피', 14),
#  ('봉산동', '카페', 14),
#  ('커피', '스타벅스', 14),
#  ('선물', '더치', 14),
#  ('이랑', '커피', 13),
#  ('부산', '카페', 13),
#  ('에스프레소', '머신', 13),
#  ('향긋', '커피', 13),
#  ('카페', '하루', 13),
#  ('커피', '얼음', 13),
#  ('커피', '스타일', 13),
#  ('스타일', '커피', 13),
#  ('커피', '부부', 13),
#  ('부부', '커피', 13),
#  ('레시', '커피', 13),
#  ('커피', '마음', 13),
#  ('그라인더', '커피', 13),
#  ('헤이', '커피', 13),
#  ('원래', '커피', 13),
#  ('외관', '커피', 13),
#  ('카페', '사이', 13),
#  ('커피', '고소', 13),
#  ('고민', '커피', 13),
#  ('커피', '화장실', 13),
#  ('커피', '한국', 13),
#  ('커피', '농장', 13),
#  ('커피', '스틱', 13),
#  ('커피', '조합', 13),
#  ('과자', '커피', 13),
#  ('커피', '선선', 13),
#  ('오픈', '시간', 13),
#  ('커피', '샌드위치', 13),
#  ('커피', '라보', 13),
#  ('회사', '커피', 13),
#  ('명절', '선물', 13),
#  ('커피', '카멜', 13),
#  ('커피', '조용', 13),
#  ('커피', '과자', 13),
#  ('머신', '구매', 13),
#  ('코로나', '커피', 13),
#  ('카페', '여행', 13),
#  ('커피', '그동안', 13),
#  ('망원역', '카페', 13),
#  ('커피', '박스', 13),
#  ('커피', '로스', 13),
#  ('달고나', '커피', 13),
#  ('커피', '도시', 13),
#  ('커피', '화이트', 13),
#  ('서울', '카페', 13),
#  ('바리스타', '커피', 13),
#  ('커피', '엄마', 13),
#  ('커피', '패키지', 13),
#  ('커피', '영업', 13),
#  ('커피', '러버', 13),
#  ('카페', '인테리어', 13),
#  ('커피', '식당', 13),
#  ('커피', '부분', 13),
#  ('더치', '원액', 13),
#  ('골목', '커피', 13),
#  ('편의점', '피니시', 13),
#  ('커피', '피니시', 13),
#  ('카페', '한잔', 13),
#  ('웨이브', '커피', 13),
#  ('아이스크림', '커피', 13),
#  ('해변', '안목', 13),
#  ('계절', '커피', 13),
#  ('카페', '맛집', 12),
#  ('커피', '간판', 12),
#  ('아이', '커피', 12),
#  ('기장', '카페', 12),
#  ('원두', '추천', 12),
#  ('저렴', '커피', 12),
#  ('이용', '커피', 12),
#  ('라고', '커피', 12),
#  ('코스', '커피', 12),
#  ('커피', '문화', 12),
#  ('커피', '아이들', 12),
#  ('커피', '차로', 12),
#  ('카페', '생각', 12),
#  ('커피', '시원', 12),
#  ('출근', '커피', 12),
#  ('드립 커피', '커피', 12),
#  ('카페', '이용', 12),
#  ('건물', '카페', 12),
#  ('종류', '커피', 12),
#  ('커피', '브라운', 12),
#  ('브라운', '커피', 12),
#  ('안목', '거리', 12),
#  ('커피', '아래', 12),
#  ('메뉴', '주문', 12),
#  ('커피', '은근', 12),
#  ('강릉', '커피콩', 12),
#  ('커피', '레시', 12),
#  ('식후', '커피', 12),
#  ('커피집', '커피', 12),
#  ('오픈', '카페', 12),
#  ('간식', '커피', 12),
#  ('사부', '커피', 12),
#  ('케이크', '커피', 12),
#  ('카페', '내부', 12),
#  ('커피', '명절', 12),
#  ('명절', '커피', 12),
#  ('입구', '카페', 12),
#  ('커피', '메가', 12),
#  ('매머드', '커피', 12),
#  ('커피', '진행', 12),
#  ('동안', '커피', 12),
#  ('평일', '커피', 12),
#  ('필요', '커피', 12),
#  ('마시기', '커피', 12),
#  ('커피', '다음', 12),
#  ('카페', '제품', 12),
#  ('드라이브', '커피', 12),
#  ('커피', '춘천', 12),
#  ('카페', '오픈', 12),
#  ('신세계백화점', '하프', 12),
#  ('카페', '하프', 12),
#  ('소개', '카페', 12),
#  ('커피', '크기', 12),
#  ('필터', '커피', 12),
#  ('커피', '정보', 12),
#  ('커피', '클래식', 12),
#  ('조용', '커피', 12),
#  ('제주', '커피', 12),
#  ('커피', '제주', 12),
#  ('아크', '세종', 12),
#  ('왕십리', '커피', 12),
#  ('카라멜', '커피', 12),
#  ('원액', '커피', 12),
#  ('플라워', '피니시', 12),
#  ('카페', '가격', 12),
#  ('아웃', '커피', 12),
#  ('초당', '찰떡', 12),
#  ('카페', '봉산동', 12),
#  ('일리', '구매', 12),
#  ('커피', '방법', 12),
#  ('커피', '계절', 12),
#  ('커피', '허전', 12),
#  ('카페', '아르', 12),
#  ('커피', '디자인', 12),
#  ('커피', '봉지', 12),
#  ('커피', '이상', 12),
#  ('커피', '인터뷰', 12),
#  ('커피', '스탠드', 12),
#  ('나주', '커피', 12),
#  ('원두', '더치', 12),
#  ('이번', '카페', 11),
#  ('커피', '구입', 11),
#  ('커피', '재료', 11),
#  ('커피', '제주도', 11),
#  ('카페', '다양', 11),
#  ('머신', '캡슐', 11),
#  ('제일', '커피', 11),
#  ('커피', '비슷', 11),
#  ('얼음', '커피', 11),
#  ('커피', '지금', 11),
#  ('핸드', '원두', 11),
#  ('커피', '용인', 11),
#  ('커피', '간단', 11),
#  ('아이스', '카페', 11),
#  ('카페', '제가', 11),
#  ('커피', '여왕', 11),
#  ('커피', '언니', 11),
#  ('제주도', '카페', 11),
#  ('일산', '카페', 11),
#  ('커피', '스타', 11),
#  ('점심', '카페', 11),
#  ('서면', '커피', 11),
#  ('머신', '회사', 11),
#  ('강릉', '여행', 11),
#  ('강릉', '강릉시', 11),
#  ('커피', '강릉시', 11),
#  ('포장', '커피', 11),
#  ('카페', '본점', 11),
#  ('강릉', '유명', 11),
#  ('커피', '동안', 11),
#  ('커피', '깔끔', 11),
#  ('안녕하세요', '머신', 11),
#  ('선선', '커피', 11),
#  ('설탕', '커피', 11),
#  ('커피', '일요일', 11),
#  ('소금', '커피', 11),
#  ('한과', '커피', 11),
#  ('샌드위치', '커피', 11),
#  ('그니', '커피', 11),
#  ('추석', '세트', 11),
#  ('커피', '할인', 11),
#  ('대흥동', '커피', 11),
#  ('커피', '바스크', 11),
#  ('메뉴', '카페', 11),
#  ('커피', '청담', 11),
#  ('커피', '성수동', 11),
#  ('커피', '치즈', 11),
#  ('커피', '케익', 11),
#  ('카페', '골목', 11),
#  ('커피', '매니아', 11),
#  ('망원역', '커피', 11),
#  ('커피', '리퍼', 11),
#  ('편의점', '맥심', 11),
#  ('출시', '커피', 11),
#  ('카페', '카페인', 11),
#  ('로스팅', '원두', 11),
#  ('커피', '도착', 11),
#  ('베이커리', '커피', 11),
#  ('커피', '루프', 11),
#  ('머신', '일리', 11),
#  ('커피', '데이트', 11),
#  ('대구', '하프', 11),
#  ('커피', '설탕', 11),
#  ('카페', '바리스타', 11),
#  ('이탈리아', '커피', 11),
#  ('여행', '카페', 11),
#  ('카페', '주차장', 11),
#  ('힐링', '커피', 11),
#  ('사르', '커피', 11),
#  ('커피', '드릴', 11),
#  ('카페', '투어', 11),
#  ('커피', '평소', 11),
#  ('커피', '만족', 11),
#  ('커피', '심플', 11),
#  ('커피', '리뷰', 11),
#  ('지금', '커피', 11),
#  ('일상', '커피', 11),
#  ('미국', '커피', 11),
#  ('카페', '로스팅', 11),
#  ('커피', '지점', 11),
#  ('샐러드', '커피', 11),
#  ('지인', '커피', 11),
#  ('커피', '건강', 10),
#  ('며칠', '커피', 10),
#  ('커피', '기장', 10),
#  ('기장', '커피', 10),
#  ('카페', '캡슐', 10),
#  ('발견', '커피', 10),
#  ('커피', '코스', 10),
#  ('커피', '테라로사', 10),
#  ('커피', '두에', 10),
#  ('문화', '커피', 10),
#  ('본점', '커피', 10),
#  ('커피', '장비', 10),
#  ('커피', '장만', 10),
#  ('카페', '용인', 10),
#  ('정도', '카페', 10),
#  ('간단', '커피', 10),
#  ('커피', '주스', 10),
#  ('호두', '강정', 10),
#  ('커피', '캠핑', 10),
#  ('카페', '헤이', 10),
#  ('주차', '가능', 10),
#  ('주차', '카페', 10),
#  ('블랙', '커피', 10),
#  ('커피', '사이', 10),
#  ('커피', '초입', 10),
#  ('커피', '카운터', 10),
#  ('커피', '기억', 10),
#  ('거리', '안목', 10),
#  ('안목', '강릉', 10),
#  ('해변', '거리', 10),
#  ('요리', '커피', 10),
#  ('커피', '서비스', 10),
#  ('커피콩', '강릉', 10),
#  ('티타임', '커피', 10),
#  ('오픈', '방문', 10),
#  ('방문', '위치', 10),
#  ('커피', '시럽', 10),
#  ('카페', '예전', 10),
#  ('경동', '한과', 10),
#  ('쿠키', '사부', 10),
#  ('고어', '라운드', 10),
#  ('고어', '쿠키', 10),
#  ('라운드', '쿠키', 10),
#  ('라보', '선물', 10),
#  ('라보', '쿠키', 10),
#  ('커피', '진한', 10),
#  ('진한', '커피', 10),
#  ('에그', '타르트', 10),
#  ('추석', '커피', 10),
#  ('커피', '맞이', 10),
#  ('카페', '출구', 10),
#  ('사이', '커피', 10),
#  ('커피', '빈티지', 10),
#  ('궁금', '커피', 10),
#  ('로스', '커피', 10),
#  ('커피', '소품', 10),
#  ('도착', '커피', 10),
#  ('버터', '커피', 10),
#  ('춘천', '도시', 10),
#  ('춘천', '페스', 10),
#  ('베이커리', '카페', 10),
#  ('가게', '커피', 10),
#  ('카페', '아침', 10),
#  ('안녕하세요', '소개', 10),
#  ('커피', '로드', 10),
#  ('카페', '아이스', 10),
#  ('조용', '카페', 10),
#  ('커피', '납품', 10),
#  ('명품', '커피', 10),
#  ('오피', '플라워', 10),
#  ('커피', '에이드', 10),
#  ('작년', '커피', 10),
#  ('커피', '덕분', 10),
#  ('편의점', '카페', 10),
#  ('운영', '커피', 10),
#  ('편의점', '신상', 10),
#  ('원주', '카페', 10),
#  ('오피', '편의점', 10),
#  ('리스', '커피', 10),
#  ('플라워', '편의점', 10),
#  ('피니시', '편의점', 10),
#  ('커피', '최고', 10),
#  ('위치', '메뉴', 10),
#  ('커피', '커피타임', 10),
#  ('네스프레소', '머신', 10),
#  ('카페', '안목', 10),
#  ('카페', '해변', 10),
#  ('커피', '울산', 10),
#  ('커피', '티라미수', 10),
#  ('커피', '클래스', 10),
#  ('티백', '커피', 10),
#  ('바캉스', '커피', 10),
#  ('카페', '이랑', 9),
#  ('커피', '이랑', 9),
#  ('하늘', '커피', 9),
#  ('선물', '강릉', 9),
#  ('친구', '카페', 9),
#  ('오랜만', '카페', 9),
#  ('커피', '가정', 9),
#  ('주변', '커피', 9),
#  ('카페', '에스프레소', 9),
#  ('커피', '대부분', 9),
#  ('카페', '라고', 9),
#  ('안녕하세요', '스팅', 9),
#  ('강릉', '본점', 9),
#  ('공장', '커피', 9),
#  ('요즘', '머신', 9),
#  ('용인', '카페', 9),
#  ('커피', '다이어트', 9),
#  ('커피', '바람', 9),
#  ('아메리카노', '카페', 9),
#  ('여왕', '커피', 9),
#  ('아침', '카페', 9),
#  ('핸드', '드립 커피', 9),
#  ('시간', '방문', 9),
#  ('커피', '구조', 9),
#  ('언니', '커피', 9),
#  ('일산', '리단', 9),
#  ('스타', '커피', 9),
#  ('커피', '달콤', 9),
#  ('사무실', '커피', 9),
#  ('머신', '자동', 9),
#  ('따뜻', '카페', 9),
#  ('커피', '광고', 9),
#  ('커피', '포장', 9),
#  ('커피', '그런지', 9),
#  ('커피', '마무리', 9),
#  ('비티', '커피', 9),
#  ('커피', '모닝커피', 9),
#  ('시럽', '커피', 9),
#  ('커피', '레몬', 9),
#  ('커피', '우리집', 9),
#  ('비엔나', '커피', 9),
#  ('사부', '고어', 9),
#  ('사부', '라운드', 9),
#  ('고어', '선물', 9),
#  ('고어', '세트', 9),
#  ('라운드', '선물', 9),
#  ('라운드', '세트', 9),
#  ('라보', '커피', 9),
#  ('할인', '커피', 9),
#  ('커피', '계단', 9),
#  ('커피', '식빵', 9),
#  ('방문', '후기', 9),
#  ('커피', '나라', 9),
#  ('테이크아웃', '커피', 9),
#  ('수제', '쿠키', 9),
#  ('외관', '카페', 9),
#  ('커피', '자세', 9),
#  ('최근', '커피', 9),
#  ('원두', '로스팅', 9),
#  ('카페', '제주도', 9),
#  ('카페인', '카페', 9),
#  ('카페', '망원역', 9),
#  ('카페', '호선', 9),
#  ('커피', '탈취', 9),
#  ('테라스', '커피', 9),
#  ('카페', '편의점', 9),
#  ('배럴', '커피', 9),
#  ('카페', '궁금', 9),
#  ('한가', '커피', 9),
#  ('카페', '주소', 9),
#  ('랜드', '커피', 9),
#  ('커피', '사고', 9),
#  ('도시', '커피', 9),
#  ('커피', '해서', 9),
#  ('커피', '호환', 9),
#  ('커피', '에티오피아', 9),
#  ('관련', '커피', 9),
#  ('엄마', '커피', 9),
#  ('산미', '커피', 9),
#  ('사진', '카페', 9),
#  ('텀블러', '커피', 9),
#  ('커피', '로우', 9),
#  ('커피', '스콘', 9),
#  ('커피', '자체', 9),
#  ('커피', '프랜차이즈', 9),
#  ('제주', '카페', 9),
#  ('헤이', '간판', 9),
#  ('카페', '아크', 9),
#  ('커피', '이날', 9),
#  ('커피', '카라멜', 9),
#  ('공부', '커피', 9),
#  ('인테리어', '커피', 9),
#  ('오피', '피니시', 9),
#  ('추천', '원두', 9),
#  ('카페', '선물', 9),
#  ('커피', '대전', 9),
#  ('매력', '커피', 9),
#  ('부여', '카페', 9),
#  ('블루', '커피', 9),
#  ('달콤', '커피', 9),
#  ('커피', '브라질', 9),
#  ('신상', '편의점', 9),
#  ('커피', '완료', 9),
#  ('버거', '초당', 9),
#  ('커피', '인증', 9),
#  ('생활', '커피', 9),
#  ('커피', '브런치', 9),
#  ('커피', '리스', 9),
#  ('이도', '커피', 9),
#  ('커피', '가게', 9),
#  ('커피', '아르', 9),
#  ('시리즈', '커피', 9),
#  ('카페', '자동', 9),
#  ('카페', '친구', 9),
#  ('커피', '모델', 9),
#  ('커피', '상태', 9),
#  ('지난주', '커피', 9),
#  ('카페', '스팅', 9),
#  ('커피', '마감', 9),
#  ('동네', '송정', 9),
#  ('맛집', '라테', 9),
#  ('커피', '데이', 9),
#  ('세계', '커피', 9),
#  ('원두', '선물', 9),
#  ('선물', '카페', 8),
#  ('커피', '인상', 8),
#  ('커피', '고려', 8),
#  ('커피', '일주일', 8),
#  ('재료', '커피', 8),
#  ('커피', '관심', 8),
#  ('안녕하세요', '이번', 8),
#  ('커피', '페어', 8),
#  ('하루', '카페', 8),
#  ('커피', '커피콩', 8),
#  ('요즘', '원두', 8),
#  ('커피', '성분', 8),
#  ('과일', '커피', 8),
#  ('요즘', '카페인', 8),
#  ('국내', '커피', 8),
#  ('커피', '냉장고', 8),
#  ('거리', '카페', 8),
#  ('카페', '유명', 8),
#  ('커피', '전포동', 8),
#  ('머신', '추천', 8),
#  ('추천', '머신', 8),
#  ('애견', '커피', 8),
#  ('동반', '커피', 8),
#  ('고소', '커피', 8),
#  ('여행', '안목', 8),
#  ('여행', '해변', 8),
#  ('거리', '해변', 8),
#  ('커피', '이벤트', 8),
#  ('드릴', '커피', 8),
#  ('커피', '커피나무', 8),
#  ('맥심', '골드', 8),
#  ('커피', '집중', 8),
#  ('야외', '커피', 8),
#  ('추천', '가격', 8),
#  ('커피', '칭찬', 8),
#  ('커피', '풍미', 8),
#  ('커피콩', '커피', 8),
#  ('출구', '커피', 8),
#  ('빙수', '커피', 8),
#  ('커피', '티타임', 8),
#  ('청주', '커피', 8),
#  ('우리집', '커피', 8),
#  ('사부', '선물', 8),
#  ('사부', '세트', 8),
#  ('라보', '세트', 8),
#  ('선물', '쿠키', 8),
#  ('세트', '쿠키', 8),
#  ('커피', '실내', 8),
#  ('커피', '동반', 8),
#  ('반죽', '커피', 8),
#  ('식빵', '커피', 8),
#  ('에그', '커피', 8),
#  ('맛집', '방문', 8),
#  ('커피', '에그', 8),
#  ('커피', '좋아서', 8),
#  ('포즈', '메뉴', 8),
#  ('커피', '수제', 8),
#  ('프롬', '카페', 8),
#  ('커피', '바로', 8),
#  ('훌륭', '커피', 8),
#  ('카페', '강릉시', 8),
#  ('오월', '커피', 8),
#  ('스팅', '카페', 8),
#  ('커피', '지도', 8),
#  ('제가', '카페', 8),
#  ('카페', '빈티지', 8),
#  ('망원역', '위치', 8),
#  ('커피', '매머드', 8),
#  ('커피', '찌꺼기', 8),
#  ('커피', '타임', 8),
#  ('커피', '참고', 8),
#  ('캡슐', '구매', 8),
#  ('주소', '영업시간', 8),
#  ('일요일', '카페', 8),
#  ('커피', '스토어', 8),
#  ('커피', '완성', 8),
#  ('구입', '커피', 8),
#  ('영업시간', '커피', 8),
#  ('리단', '캐제', 8),
#  ('캐제', '커피', 8),
#  ('커피', '수입', 8),
#  ('카페', '판매', 8),
#  ('카페', '종류', 8),
#  ('커피', '규모', 8),
#  ('카페', '테이블', 8),
#  ('호환', '캡슐', 8),
#  ('로드', '커피', 8),
#  ('모닝커피', '커피', 8),
#  ('자연', '커피', 8),
#  ('식물', '커피', 8),
#  ('커피', '음식', 8),
#  ('대표', '커피', 8),
#  ('강릉', '초당', 8),
#  ('가루', '커피', 8),
#  ('커피', '대표', 8),
#  ('커피', '완전', 8),
#  ('커피', '이탈리아', 8),
#  ('미티', '커피', 8),
#  ('에디션', '커피', 8),
#  ('토니', '커피', 8),
#  ('커피', '간식', 8),
#  ('배전', '커피', 8),
#  ('다음', '커피', 8),
#  ('커피', '도넛', 8),
#  ('커피', '경화', 8),
#  ('도넛', '커피', 8),
#  ('성수동', '커피', 8),
#  ('대전', '카페', 8),
#  ('세종', '아크', 8),
#  ...]

# %%
def sna_graph(word_data, NETWORK_MAX):
    G = nx.Graph()
    i = 0
