# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform
if platform.system() == 'Windows':
    matplotlib.rc('font', family='Malgun Gothic')

# %matplotlib inline    
    
df=pd.read_csv('data/서울시 인구현황_구.txt', sep='\t')
df
# Out:
#        기간  자치구         세대          인구       인구.1       인구.2     인구.3     인구.4  \
# 0      기간  자치구         세대          합계         합계         합계      한국인      한국인
# 1      기간  자치구         세대           계         남자         여자        계       남자
# 2    1991   합계  3,330,317  10,904,527  5,485,353  5,419,174        …        …
# 3    1991  종로구     78,169     236,806    119,127    117,679        …        …
# 4    1991   중구     61,495     184,142     93,312     90,830        …        …
# ..    ...  ...        ...         ...        ...        ...      ...      ...
# 765  2020  관악구    274,811     509,803    255,211    254,592  495,060  248,339
# 766  2020  서초구    173,502     429,025    205,282    223,743  425,126  203,359
# 767  2020  강남구    234,872     544,055    260,378    283,677  539,231  257,999
# 768  2020  송파구    281,959     673,926    325,080    348,846  667,960  322,299
# 769  2020  강동구    196,499     463,998    228,044    235,954  459,970  226,216
#
# ...

# %%
df=pd.read_csv('data/서울시 인구현황_구.txt', sep='\t', header=1)
df
# Out:
#        기간  자치구         세대          합계       합계.1       합계.2      한국인    한국인.1  \
# 0      기간  자치구         세대           계         남자         여자        계       남자
# 1    1991   합계  3,330,317  10,904,527  5,485,353  5,419,174        …        …
# 2    1991  종로구     78,169     236,806    119,127    117,679        …        …
# 3    1991   중구     61,495     184,142     93,312     90,830        …        …
# 4    1991  용산구     96,696     294,341    147,914    146,427        …        …
# ..    ...  ...        ...         ...        ...        ...      ...      ...
# 764  2020  관악구    274,811     509,803    255,211    254,592  495,060  248,339
# 765  2020  서초구    173,502     429,025    205,282    223,743  425,126  203,359
# 766  2020  강남구    234,872     544,055    260,378    283,677  539,231  257,999
# 767  2020  송파구    281,959     673,926    325,080    348,846  667,960  322,299
# 768  2020  강동구    196,499     463,998    228,044    235,954  459,970  226,216
#
# ...

# %%
df.drop(0, inplace=True)
df
# Out:
#        기간  자치구         세대          합계       합계.1       합계.2      한국인    한국인.1  \
# 1    1991   합계  3,330,317  10,904,527  5,485,353  5,419,174        …        …
# 2    1991  종로구     78,169     236,806    119,127    117,679        …        …
# 3    1991   중구     61,495     184,142     93,312     90,830        …        …
# 4    1991  용산구     96,696     294,341    147,914    146,427        …        …
# 5    1991  성동구    244,272     789,014    401,375    387,639        …        …
# ..    ...  ...        ...         ...        ...        ...      ...      ...
# 764  2020  관악구    274,811     509,803    255,211    254,592  495,060  248,339
# 765  2020  서초구    173,502     429,025    205,282    223,743  425,126  203,359
# 766  2020  강남구    234,872     544,055    260,378    283,677  539,231  257,999
# 767  2020  송파구    281,959     673,926    325,080    348,846  667,960  322,299
# 768  2020  강동구    196,499     463,998    228,044    235,954  459,970  226,216
#
# ...

# %%
#세대 컬럼도 삭제
dfgner = df.drop(['세대', '인구밀도', '인구밀도.1', '세대당인구'], axis=1)
dfgner
# Out:
#        기간  자치구          합계       합계.1       합계.2      한국인    한국인.1    한국인.2  \
# 1    1991   합계  10,904,527  5,485,353  5,419,174        …        …        …
# 2    1991  종로구     236,806    119,127    117,679        …        …        …
# 3    1991   중구     184,142     93,312     90,830        …        …        …
# 4    1991  용산구     294,341    147,914    146,427        …        …        …
# 5    1991  성동구     789,014    401,375    387,639        …        …        …
# ..    ...  ...         ...        ...        ...      ...      ...      ...
# 764  2020  관악구     509,803    255,211    254,592  495,060  248,339  246,721
# 765  2020  서초구     429,025    205,282    223,743  425,126  203,359  221,767
# 766  2020  강남구     544,055    260,378    283,677  539,231  257,999  281,232
# 767  2020  송파구     673,926    325,080    348,846  667,960  322,299  345,661
# 768  2020  강동구     463,998    228,044    235,954  459,970  226,216  233,754
#
#       등록외국인 등록외국인.1 등록외국인.2 65세이상고령자
# ...

# %% [markdown]
# 년도, 자치구, 총인구, 총인구(남), 총인구(여), 내국인, 내국인(남), 내국인(여), 외국인, 외국인(남), 외국인(여), 65세 이상

# %%
dfgner.columns = ['년도', '자치구', '총인구', '총인구(남)', '총인구(여)', '내국인', '내국인(남)', '내국인(여)', '외국인', '외국인(남)', '외국인(여)', '65세 이상']
dfgner
# Out:
#        년도  자치구         총인구     총인구(남)     총인구(여)      내국인   내국인(남)   내국인(여)  \
# 1    1991   합계  10,904,527  5,485,353  5,419,174        …        …        …
# 2    1991  종로구     236,806    119,127    117,679        …        …        …
# 3    1991   중구     184,142     93,312     90,830        …        …        …
# 4    1991  용산구     294,341    147,914    146,427        …        …        …
# 5    1991  성동구     789,014    401,375    387,639        …        …        …
# ..    ...  ...         ...        ...        ...      ...      ...      ...
# 764  2020  관악구     509,803    255,211    254,592  495,060  248,339  246,721
# 765  2020  서초구     429,025    205,282    223,743  425,126  203,359  221,767
# 766  2020  강남구     544,055    260,378    283,677  539,231  257,999  281,232
# 767  2020  송파구     673,926    325,080    348,846  667,960  322,299  345,661
# 768  2020  강동구     463,998    228,044    235,954  459,970  226,216  233,754
#
#         외국인 외국인(남) 외국인(여)  65세 이상
# ...

# %%
dfgner.columns
# Out:
# Index(['년도', '자치구', '총인구', '총인구(남)', '총인구(여)', '내국인', '내국인(남)', '내국인(여)',
#        '외국인', '외국인(남)', '외국인(여)', '65세 이상'],
#       dtype='object')

# %%
#dfgner.rename(columns={'합계':'총인구', 'ㅇㅇ':'ㅇㄷ'}) 이런 식으로 바꿔도 됨

# %%
dfgner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768 entries, 1 to 768
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      768 non-null    object
#  1   자치구     768 non-null    object
#  2   총인구     768 non-null    object
#  3   총인구(남)  768 non-null    object
#  4   총인구(여)  768 non-null    object
#  5   내국인     768 non-null    object
#  6   내국인(남)  768 non-null    object
#  7   내국인(여)  768 non-null    object
#  8   외국인     768 non-null    object
#  9   외국인(남)  768 non-null    object
#  10  외국인(여)  768 non-null    object
#  11  65세 이상  768 non-null    object
# dtypes: object(12)
# memory usage: 78.0+ KB

# %%
df3['총인구(남)'] = dfgner['총인구(남)'].str.replace(',', '').astype('int64')
df3['총인구(여)'] = dfgner['총인구(여)'].str.replace(',', '').astype('int64')
df3['총인구'] = dfgner['총인구'].str.replace(',', '').astype('int64')
df3['년도'] = dfgner['년도'].str.replace(',', '').astype('int64')

print(df3)
# Out:
#        년도  자치구       총인구   총인구(남)   총인구(여)      내국인   내국인(남)   내국인(여)     외국인  \
# 1    1991   합계  10904527  5485353  5419174        …        …        …       …
# 2    1991  종로구    236806   119127   117679        …        …        …       …
# 3    1991   중구    184142    93312    90830        …        …        …       …
# 4    1991  용산구    294341   147914   146427        …        …        …       …
# 5    1991  성동구    789014   401375   387639        …        …        …       …
# ..    ...  ...       ...      ...      ...      ...      ...      ...     ...
# 764  2020  관악구    509803   255211   254592  495,060  248,339  246,721  14,743
# 765  2020  서초구    429025   205282   223743  425,126  203,359  221,767   3,899
# 766  2020  강남구    544055   260378   283677  539,231  257,999  281,232   4,824
# 767  2020  송파구    673926   325080   348846  667,960  322,299  345,661   5,966
# 768  2020  강동구    463998   228044   235954  459,970  226,216  233,754   4,028
#
#     외국인(남) 외국인(여)  65세 이상
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768 entries, 1 to 768
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      768 non-null    int64
#  1   자치구     768 non-null    object
#  2   총인구     768 non-null    int64
#  3   총인구(남)  768 non-null    int64
#  4   총인구(여)  768 non-null    int64
#  5   내국인     768 non-null    object
#  6   내국인(남)  768 non-null    object
#  7   내국인(여)  768 non-null    object
#  8   외국인     768 non-null    object
#  9   외국인(남)  768 non-null    object
#  10  외국인(여)  768 non-null    object
#  11  65세 이상  768 non-null    object
# dtypes: int64(4), object(8)
# memory usage: 78.0+ KB

# %% [markdown]
# 총인구(남)/총인구(여) 값을 그래프로 작성하시오

# %%
df4 = df3[['년도','자치구','총인구','총인구(남)','총인구(여)']]
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768 entries, 1 to 768
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      768 non-null    int64
#  1   자치구     768 non-null    object
#  2   총인구     768 non-null    int64
#  3   총인구(남)  768 non-null    int64
#  4   총인구(여)  768 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 36.0+ KB

# %%
df4
# Out:
#        년도  자치구       총인구   총인구(남)   총인구(여)
# 1    1991   합계  10904527  5485353  5419174
# 2    1991  종로구    236806   119127   117679
# 3    1991   중구    184142    93312    90830
# 4    1991  용산구    294341   147914   146427
# 5    1991  성동구    789014   401375   387639
# ..    ...  ...       ...      ...      ...
# 764  2020  관악구    509803   255211   254592
# 765  2020  서초구    429025   205282   223743
# 766  2020  강남구    544055   260378   283677
# 767  2020  송파구    673926   325080   348846
# 768  2020  강동구    463998   228044   235954
#
# [768 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
df5 = df4.groupby(['년도'])[['총인구(남)', '총인구(여)']].sum()
df5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-3d3cf8598264> in <module>
# ----> 1 df5 = df4.groupby(['년도'])[['총인구(남)', '총인구(여)']].sum()
#       2 df5
#
# NameError: name 'df4' is not defined

# %%
import numpy as np
import seaborn as sns

# %%
y = df5['총인구(남)']/df5['총인구(여)']
plt.plot(y, color='pink')
plt.xlabel('year')
plt.ylabel('M/F')
plt.title('Total', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Total')

# %%
grouped = df4.groupby(['자치구', '년도'])[['총인구(남)', '총인구(여)']]

# %%
grouped.plot.

# %%
gu = input('조회할 구 이름을 입력하세요(예:종로구) : ')

df5 = df4[df4['자치구']==gu]
plt.plot(df5['년도'], df5['총인구'])
plt.xlabel('year')
plt.ylabel('population')
plt.show()

plt.plot(df5['년도'], df5['총인구(남)'], label='M')
plt.plot(df5['년도'], df5['총인구(여)'], label='F')
plt.legend()
plt.show()
# Out:
# 조회할 구 이름을 입력하세요(예:종로구) : 종로구

# %%
import pandas as pd

# %%
wifi = pd.read_csv('data/서울시 공공와이파이 서비스 위치 정보.csv', encoding='euc-kr')

# %%
import numpy as np

# %%
wifi
# Out:
#            관리번호   자치구    와이파이명         도로명주소        상세주소 설치위치(층)  \
# 0      ARI00001  서대문구  상수도사업본부  서대문구 서소문로 51       본관 1F       1
# 1      ARI00002  서대문구  상수도사업본부  서대문구 서소문로 51       본관 2F       2
# 2      ARI00003  서대문구  상수도사업본부  서대문구 서소문로 51       본관 2F       2
# 3      ARI00004  서대문구  상수도사업본부  서대문구 서소문로 51       본관 2F       2
# 4      ARI00005  서대문구  상수도사업본부  서대문구 서소문로 51       본관 2F       2
# ...         ...   ...      ...           ...         ...     ...
# 13530  YS170021   용산구  꿈나무종합타운     원효로 1가 25  꿈나무종합타운 5층      5층
# 13531  YS170022   용산구  꿈나무종합타운     원효로 1가 25  꿈나무종합타운 5층      5층
# 13532  YS170023   용산구  꿈나무종합타운     원효로 1가 25  꿈나무종합타운 5층      5층
# 13533  YS170024   용산구  꿈나무종합타운     원효로 1가 25  꿈나무종합타운 5층      5층
# 13534  YS180001   용산구   용산보건분소   원효로1가 26-15     시설관리팀 내      3층
#
#                   설치유형     설치기관   서비스구분       망종류  설치년도 실내외구분  wifi접속환경  \
# 0       7-1. 커뮤니티 - 행정  서울시(AP)  공공WiFi  수도사업소자가망  2014    실내       NaN
# ...

# %%
wifi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13535 entries, 0 to 13534
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   관리번호      13535 non-null  object
#  1   자치구       13535 non-null  object
#  2   와이파이명     13535 non-null  object
#  3   도로명주소     13469 non-null  object
#  4   상세주소      12101 non-null  object
#  5   설치위치(층)   4562 non-null   object
#  6   설치유형      13535 non-null  object
#  7   설치기관      13535 non-null  object
#  8   서비스구분     13535 non-null  object
#  9   망종류       13535 non-null  object
#  10  설치년도      13535 non-null  int64
#  11  실내외구분     13535 non-null  object
#  12  wifi접속환경  0 non-null      float64
#  13  X좌표       13535 non-null  float64
#  14  Y좌표       13535 non-null  float64
#  15  작업일자      13535 non-null  object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 1.7+ MB

# %%
wifi.head(1)
# Out:
#        관리번호   자치구    와이파이명         도로명주소   상세주소 설치위치(층)            설치유형  \
# 0  ARI00001  서대문구  상수도사업본부  서대문구 서소문로 51  본관 1F       1  7-1. 커뮤니티 - 행정
#
#       설치기관   서비스구분       망종류  설치년도 실내외구분  wifi접속환경        X좌표        Y좌표  \
# 0  서울시(AP)  공공WiFi  수도사업소자가망  2014    실내       NaN  126.96675  37.561924
#
#                     작업일자
# 0  2021-09-06 10:57:42.0

# %% [markdown]
# 각 구별 공공데이터 설치 갯수를 파악하세요

# %%
gu = str(input('찾고 싶은 구를 입력하세요 : '))

count = 0
for i in range(13535):
    if wifi['자치구'][i] == gu:
        count += 1

print(count)
# Out:
# 찾고 싶은 구를 입력하세요 : 서대문구
# 513

# %%
wifidata = wifi.groupby('자치구').count().관리번호

# %%
wifidata
# Out:
# 자치구
# 강남구      539
# 강동구      433
# 강북구      274
# 강서구     1323
# 과천시       13
# 관악구      292
# 광진구      276
# 구로구      841
# 금천구      445
# 노원구      685
# 도봉구      584
# 동대문구     358
# 동작구      225
# 마포구      704
# 서대문구     513
# 서초구      582
# 성동구      860
# 성북구      247
# 송파구      338
# 양천구      616
# 영등포구     456
# 용산구      433
# 은평구      931
# 종로구      277
# 중구       983
# 중랑구      307
# Name: 관리번호, dtype: int64

# %%
wifidict = {}
for i in wifi['자치구']:
    if i in wifidict:
        wifidict[i] += 1
    else:
        wifidict[i] = 1

wifidict
# Out:
# {'서대문구': 513,
#  '중구': 983,
#  '성동구': 860,
#  '강북구': 274,
#  '양천구': 616,
#  '동작구': 225,
#  '강남구': 539,
#  '강동구': 433,
#  '광진구': 276,
#  '강서구': 1323,
#  '관악구': 292,
#  '구로구': 841,
#  '금천구': 445,
#  '노원구': 685,
#  '도봉구': 584,
#  '동대문구': 358,
#  '마포구': 704,
#  '서초구': 582,
#  '성북구': 247,
#  '송파구': 338,
#  '영등포구': 456,
#  '용산구': 433,
#  '은평구': 931,
#  '종로구': 277,
#  '중랑구': 307,
#  '과천시': 13}

# %%
wifidata1 = wifi.value_counts(wifi['자치구'])
wifidata2 = pd.DataFrame(wifidata1)
wifidata2 = wifidata2.rename(columns={0:'설치현황'})
wifidata2
# Out:
#       설치현황
# 자치구
# 강서구   1323
# 중구     983
# 은평구    931
# 성동구    860
# 구로구    841
# 마포구    704
# 노원구    685
# 양천구    616
# 도봉구    584
# 서초구    582
# 강남구    539
# 서대문구   513
# 영등포구   456
# 금천구    445
# 강동구    433
# 용산구    433
# 동대문구   358
# 송파구    338
# 중랑구    307
# 관악구    292
# 종로구    277
# 광진구    276
# 강북구    274
# 성북구    247
# 동작구    225
# 과천시     13

# %%
wifidata[0]
# Out:
# 1323

# %%
A = list(wifidict.keys())
A
# Out:
# ['서대문구',
#  '중구',
#  '성동구',
#  '강북구',
#  '양천구',
#  '동작구',
#  '강남구',
#  '강동구',
#  '광진구',
#  '강서구',
#  '관악구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '마포구',
#  '서초구',
#  '성북구',
#  '송파구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중랑구',
#  '과천시']

# %%
import seaborn as sns

# %%
wifidata1.plot.bar()
# Out:
# <AxesSubplot:xlabel='자치구'>

# %%
wifidata2.plot.bar()
# Out:
# <AxesSubplot:xlabel='자치구'>

# %%
wifidata2
# Out:
#       설치현황
# 자치구
# 강서구   1323
# 중구     983
# 은평구    931
# 성동구    860
# 구로구    841
# 마포구    704
# 노원구    685
# 양천구    616
# 도봉구    584
# 서초구    582
# 강남구    539
# 서대문구   513
# 영등포구   456
# 금천구    445
# 강동구    433
# 용산구    433
# 동대문구   358
# 송파구    338
# 중랑구    307
# 관악구    292
# 종로구    277
# 광진구    276
# 강북구    274
# 성북구    247
# 동작구    225
# 과천시     13

# %%
import seaborn as sns

# %%
plt.figure(figsize=(17,8))
bp = sns.barplot(x=wifidata2.index, y='설치현황', data= wifidata2)
bp.set_title('서울시 공공wifi 설치현황', fontsize=30)
bp.set_xlabel('지역명', fontsize=20)
bp.set_ylabel('설치수(개)', fontsize=20)

for i in bp.patches:
    bp.annotate('%d'%i.get_height(), (i.get_x()+i.get_width()/2, i.get_height()), ha='center', va='bottom')

plt.grid(axis='y', alpha=0.5)

# %%
for i in bp.patches:
    print(i)
# Out:
# Rectangle(xy=(-0.4, 0), width=0.8, height=1323, angle=0)
# Rectangle(xy=(0.6, 0), width=0.8, height=983, angle=0)
# Rectangle(xy=(1.6, 0), width=0.8, height=931, angle=0)
# Rectangle(xy=(2.6, 0), width=0.8, height=860, angle=0)
# Rectangle(xy=(3.6, 0), width=0.8, height=841, angle=0)
# Rectangle(xy=(4.6, 0), width=0.8, height=704, angle=0)
# Rectangle(xy=(5.6, 0), width=0.8, height=685, angle=0)
# Rectangle(xy=(6.6, 0), width=0.8, height=616, angle=0)
# Rectangle(xy=(7.6, 0), width=0.8, height=584, angle=0)
# Rectangle(xy=(8.6, 0), width=0.8, height=582, angle=0)
# Rectangle(xy=(9.6, 0), width=0.8, height=539, angle=0)
# Rectangle(xy=(10.6, 0), width=0.8, height=513, angle=0)
# Rectangle(xy=(11.6, 0), width=0.8, height=456, angle=0)
# Rectangle(xy=(12.6, 0), width=0.8, height=445, angle=0)
# Rectangle(xy=(13.6, 0), width=0.8, height=433, angle=0)
# Rectangle(xy=(14.6, 0), width=0.8, height=433, angle=0)
# Rectangle(xy=(15.6, 0), width=0.8, height=358, angle=0)
# ...

# %%
import pandas as pd

df = pd.read_csv('./auto-mpg.csv', header=None)
df
# Out:
#        0          1             2           3       4             5  \
# 0    mpg  cylinders  displacement  horsepower  weight  acceleration
# 1     18          8           307         130    3504            12
# 2     15          8           350         165    3693          11.5
# 3     18          8           318         150    3436            11
# 4     16          8           304         150    3433            12
# ..   ...        ...           ...         ...     ...           ...
# 394   27          4           140          86    2790          15.6
# 395   44          4            97          52    2130          24.6
# 396   32          4           135          84    2295          11.6
# 397   28          4           120          79    2625          18.6
# 398   31          4           119          82    2720          19.4
#
#               6       7                          8
# 0    model year  origin                   car name
# ...

# %%
df.drop(0, inplace=True)

# %%
df
# Out:
#       0  1    2    3     4     5   6  7                          8
# 1    18  8  307  130  3504    12  70  1  chevrolet chevelle malibu
# 2    15  8  350  165  3693  11.5  70  1          buick skylark 320
# 3    18  8  318  150  3436    11  70  1         plymouth satellite
# 4    16  8  304  150  3433    12  70  1              amc rebel sst
# 5    17  8  302  140  3449  10.5  70  1                ford torino
# ..   .. ..  ...  ...   ...   ...  .. ..                        ...
# 394  27  4  140   86  2790  15.6  82  1            ford mustang gl
# 395  44  4   97   52  2130  24.6  82  2                  vw pickup
# 396  32  4  135   84  2295  11.6  82  1              dodge rampage
# 397  28  4  120   79  2625  18.6  82  1                ford ranger
# 398  31  4  119   82  2720  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# 열 이름 : '연비', '실린더수', '배기량', '출력', '차중', '가속능력', '출시년도', '제조국', '모델명'

# %%
df.columns= ['연비', '실린더수', '배기량', '출력', '차중', '가속능력', '출시년도', '제조국', '모델명']
df
# Out:
#      연비 실린더수  배기량   출력    차중  가속능력 출시년도 제조국                        모델명
# 1    18    8  307  130  3504    12   70   1  chevrolet chevelle malibu
# 2    15    8  350  165  3693  11.5   70   1          buick skylark 320
# 3    18    8  318  150  3436    11   70   1         plymouth satellite
# 4    16    8  304  150  3433    12   70   1              amc rebel sst
# 5    17    8  302  140  3449  10.5   70   1                ford torino
# ..   ..  ...  ...  ...   ...   ...  ...  ..                        ...
# 394  27    4  140   86  2790  15.6   82   1            ford mustang gl
# 395  44    4   97   52  2130  24.6   82   2                  vw pickup
# 396  32    4  135   84  2295  11.6   82   1              dodge rampage
# 397  28    4  120   79  2625  18.6   82   1                ford ranger
# 398  31    4  119   82  2720  19.4   82   1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df['배기량']
# Out:
# 1      307
# 2      350
# 3      318
# 4      304
# 5      302
#       ...
# 394    140
# 395     97
# 396    135
# 397    120
# 398    119
# Name: 배기량, Length: 398, dtype: object

# %%
import numpy as np

# %%
df1['연비'] = df['연비'].astype('float64')
df1['실린더수'] = df['실린더수'].astype('int64')
df1['배기량'] = df['배기량'].str.replace('?' , '0').astype('float64')
df1['출력'] = df['출력'].str.replace('?' , '0').astype('int64')
df1['차중'] = df['차중'].astype('int64')
df1['가속능력'] = df['가속능력'].astype('float64')
df1['출시년도'] = df['출시년도'].astype('int64')
# Out:
# <ipython-input-44-baea97bf16fd>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df1['배기량'] = df['배기량'].str.replace('?' , '0').astype('float64')
# <ipython-input-44-baea97bf16fd>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df1['출력'] = df['출력'].str.replace('?' , '0').astype('int64')

# %%
df1
# Out:
# 1                                                    18.0
# 2                                                    15.0
# 3                                                    18.0
# 4                                                    16.0
# 5                                                    17.0
#                               ...
# 배기량     1      307.0
# 2      350.0
# 3      318.0
# 4      ...
# 출력      1      130
# 2      165
# 3      150
# 4      150
# 5 ...
# 차중      1      3504
# 2      3693
# 3      3436
# 4      343...
# 가속능력    1      12.0
# 2      11.5
# 3      11.0
# 4      12....
# 출시년도    1      70
# 2      70
# 3      70
# 4      70
# 5     ...
# Name: 연비, Length: 405, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-42a2b2b82758> in <module>
# ----> 1 df = df.str.replace('?','0').astype({'연비' : float, '실린더수' : int, '배기량':float, '출력':float, '차중':float, '가속능력':float, '출시년도':int, '제조국':int})
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
for temp in df.columns:
    try:
        df[temp] = df[temp].str.replace('?','0')
    except:
        print('오류났어요' + temp)
        
        
# try 만약 오류가 발생시 예외처리
# Out:
# <ipython-input-50-5d73ca9ebb65>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df[temp] = df[temp].str.replace('?','0')

# %%
df = df.astype({'연비' : float, '실린더수' : int, '배기량':float, '출력':float, '차중':float, '가속능력':float, '출시년도':int, '제조국':int})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 1 to 398
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연비      398 non-null    float64
#  1   실린더수    398 non-null    int32
#  2   배기량     398 non-null    float64
#  3   출력      398 non-null    float64
#  4   차중      398 non-null    float64
#  5   가속능력    398 non-null    float64
#  6   출시년도    398 non-null    int32
#  7   제조국     398 non-null    int32
#  8   모델명     398 non-null    object
# dtypes: float64(5), int32(3), object(1)
# memory usage: 26.4+ KB

# %%
df.describe()
# Out:
#                연비        실린더수         배기량          출력           차중  \
# count  398.000000  398.000000  398.000000  398.000000   398.000000
# mean    23.514573    5.454774  193.425879  102.894472  2970.424623
# std      7.815984    1.701004  104.269838   40.269544   846.841774
# min      9.000000    3.000000   68.000000    0.000000  1613.000000
# 25%     17.500000    4.000000  104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000  148.500000   92.000000  2803.500000
# 75%     29.000000    8.000000  262.000000  125.000000  3608.000000
# max     46.600000    8.000000  455.000000  230.000000  5140.000000
#
#              가속능력        출시년도         제조국
# count  398.000000  398.000000  398.000000
# mean    15.568090   76.010050    1.572864
# std      2.757689    3.697627    0.802055
# min      8.000000   70.000000    1.000000
# 25%     13.825000   73.000000    1.000000
# 50%     15.500000   76.000000    1.000000
# 75%     17.175000   79.000000    2.000000
# ...

# %%
df.count()
# Out:
# 연비      398
# 실린더수    398
# 배기량     398
# 출력      398
# 차중      398
# 가속능력    398
# 출시년도    398
# 제조국     398
# 모델명     398
# dtype: int64

# %%
df['연비'].mean()
# Out:
# 23.514572864321615

# %%
df.corr()
# Out:
#             연비      실린더수       배기량        출력        차중      가속능력      출시년도  \
# 연비    1.000000 -0.775396 -0.804203 -0.754276 -0.831741  0.420289  0.579267
# 실린더수 -0.775396  1.000000  0.950721  0.821656  0.896017 -0.505419 -0.348746
# 배기량  -0.804203  0.950721  1.000000  0.871927  0.932824 -0.543684 -0.370164
# 출력   -0.754276  0.821656  0.871927  1.000000  0.837987 -0.673940 -0.411587
# 차중   -0.831741  0.896017  0.932824  0.837987  1.000000 -0.417457 -0.306564
# 가속능력  0.420289 -0.505419 -0.543684 -0.673940 -0.417457  1.000000  0.288137
# 출시년도  0.579267 -0.348746 -0.370164 -0.411587 -0.306564  0.288137  1.000000
# 제조국   0.563450 -0.562543 -0.609409 -0.418636 -0.581024  0.205873  0.180662
#
#            제조국
# 연비    0.563450
# 실린더수 -0.562543
# 배기량  -0.609409
# 출력   -0.418636
# 차중   -0.581024
# 가속능력  0.205873
# 출시년도  0.180662
# 제조국   1.000000

# %%
import pandas as pd
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform
if platform.system() == 'Windows':
    matplotlib.rc('font', family='Malgun Gothic')

# %matplotlib inline

# %%
colormap = plt.cm.PuBu
plt.figure(figsize=(10,8))
plt.title('자동차 상관관계 분석', y=1.05, size=15)
sns.heatmap(df.corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={'size':16})
# Out:
# C:\Users\kimtj\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\kimtj\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:title={'center':'자동차 상관관계 분석'}>

# %%
df_crime = pd.read_csv('crimeSeoul.csv', encoding='euc-kr')
df_police = pd.read_csv('police.csv', encoding='euc-kr')

# %%
df_crime.head(2)
# Out:
#    관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 0  중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1  종로서      3      3      6      5    115     98  1,070   413  1,278  1,070

# %%
df_police.head(2)
# Out:
#      청      서 지구대파출소         X좌표       Y좌표                     주소
# 0  강원청  강릉경찰서  강동파출소  128.978300  37.72776  강원도 강릉시 강동면 안인리 764-1
# 1  강원청  강릉경찰서  강릉경찰서  128.906763  37.76870           강릉시 포남동 1113

# %%
df_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   관서명     31 non-null     object
#  1   살인 발생   31 non-null     int64
#  2   살인 검거   31 non-null     int64
#  3   강도 발생   31 non-null     int64
#  4   강도 검거   31 non-null     int64
#  5   강간 발생   31 non-null     int64
#  6   강간 검거   31 non-null     int64
#  7   절도 발생   31 non-null     object
#  8   절도 검거   31 non-null     object
#  9   폭력 발생   31 non-null     object
#  10  폭력 검거   31 non-null     object
# dtypes: int64(6), object(5)
# memory usage: 2.8+ KB

# %%
df_police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2264 entries, 0 to 2263
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   청       2264 non-null   object
#  1   서       2264 non-null   object
#  2   지구대파출소  2264 non-null   object
#  3   X좌표     2264 non-null   float64
#  4   Y좌표     2264 non-null   float64
#  5   주소      2264 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 106.2+ KB

# %%
nameresult = []
for i in df_crime['관서명']:
    nameresult.append('서울'+ i[:-1] + '경찰서')
    
print(nameresult)

df_crime['관서명'] = nameresult
df_crime
# Out:
# ['서울중부경찰서', '서울종로경찰서', '서울남대문경찰서', '서울서대문경찰서', '서울혜화경찰서', '서울용산경찰서', '서울성북경찰서', '서울동대문경찰서', '서울마포경찰서', '서울영등포경찰서', '서울성동경찰서', '서울동작경찰서', '서울광진경찰서', '서울서부경찰서', '서울강북경찰서', '서울금천경찰서', '서울중랑경찰서', '서울강남경찰서', '서울관악경찰서', '서울강서경찰서', '서울강동경찰서', '서울종암경찰서', '서울구로경찰서', '서울서초경찰서', '서울양천경찰서', '서울송파경찰서', '서울노원경찰서', '서울방배경찰서', '서울은평경찰서', '서울도봉경찰서', '서울수서경찰서']
#          관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 0    서울중부경찰서      2      2      3      2    105     65  1,395    477  1,355
# 1    서울종로경찰서      3      3      6      5    115     98  1,070    413  1,278
# 2   서울남대문경찰서      1      0      6      4     65     46  1,153    382    869
# 3   서울서대문경찰서      2      2      5      4    154    124  1,812    738  2,056
# 4    서울혜화경찰서      3      2      5      4     96     63  1,114    424  1,015
# 5    서울용산경찰서      5      5     14     14    194    173  1,557    587  2,050
# 6    서울성북경찰서      2      2      2      1     86     71    953    409  1,194
# ...

# %%
police = df_police.loc[df_police['청']=='서울청', :]
police
# Out:
#         청        서   지구대파출소         X좌표        Y좌표                주소
# 1207  서울청  서울강남경찰서   논현1파출소  127.029316  37.513791     강남구 논현동 58-13
# 1208  서울청  서울강남경찰서   논현2파출소  127.033875  37.515220     강남구 논현동 89-13
# 1209  서울청  서울강남경찰서   삼성1파출소  127.060440  37.514852     강남구 삼성동 107-3
# 1210  서울청  서울강남경찰서   삼성2파출소  127.048063  37.511289     강남구 삼성동 114-6
# 1211  서울청  서울강남경찰서  서울강남경찰서  127.067177  37.509036       강남구 대치동 998
# ...   ...      ...      ...         ...        ...               ...
# 1476  서울청  서울혜화경찰서  종로5가파출소  127.001606  37.570727    종로구 종로5가 138-1
# 1477  서울청  서울혜화경찰서    창신파출소  127.013702  37.578482  종로구 창신3동 23-373호
# 1478  서울청  서울혜화경찰서    혜화파출소  127.001422  37.586135      종로구 혜화동 93-1
# 1479  서울청  서울혜화경찰서    효제파출소  127.003606  37.574259     종로구 충신동 105번지
# 1480  서울청      서울청      서울청  126.972072  37.575060     종로구 내자동 20-11
#
# [274 rows x 6 columns]

# %%
# police['주소'] = police['주소'].str.replace('서울시', '')
# police['주소'] = police['주소'].str.replace('서울특별시', '')
# police['주소'] = police['주소'].str.replace(' ', '')

juso = []
for i in police['주소']:
    j = i[0:4]
    if j[3] == '구':
        j = i[0:4]
        juso.append(j)
    if j[2] == '구':
        j = i[0:3]
        juso.append(j)
    if j[1] == '구':
        j = i[0:2]
        juso.append(j)

print(juso)
# Out:
# ['강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강북구', '강북구', '강북구', '강북구', '강북구', '강북구', '강북구', '강북구', '강북구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', '광진구', '광진구구', '광진구', '광진구', '광진구구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '구로구', '구로구', '구로구', '구로구구', '구로구', '구로구구', '구로구', '구로구구', '구로구', '구로구구', '구로구', '구로구', '구로구', '금천구', '금천구', '금천구', '금천구', '금천구', '금천구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '도봉구', '도봉구', '도봉구', '도봉구', '도봉구', '도봉구', '도봉구', '도봉구', '도봉구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '시마포구', '서초구', '서초구', '서초구', '서초구', '서초구',
# ...

# %%
a = police['주소'].drop('서울특별시')

# %%
b = police[police['주소'].str.contains('구 ')]
b
# Out:
#         청        서   지구대파출소         X좌표        Y좌표                주소
# 1207  서울청  서울강남경찰서   논현1파출소  127.029316  37.513791     강남구 논현동 58-13
# 1208  서울청  서울강남경찰서   논현2파출소  127.033875  37.515220     강남구 논현동 89-13
# 1209  서울청  서울강남경찰서   삼성1파출소  127.060440  37.514852     강남구 삼성동 107-3
# 1210  서울청  서울강남경찰서   삼성2파출소  127.048063  37.511289     강남구 삼성동 114-6
# 1211  서울청  서울강남경찰서  서울강남경찰서  127.067177  37.509036       강남구 대치동 998
# ...   ...      ...      ...         ...        ...               ...
# 1476  서울청  서울혜화경찰서  종로5가파출소  127.001606  37.570727    종로구 종로5가 138-1
# 1477  서울청  서울혜화경찰서    창신파출소  127.013702  37.578482  종로구 창신3동 23-373호
# 1478  서울청  서울혜화경찰서    혜화파출소  127.001422  37.586135      종로구 혜화동 93-1
# 1479  서울청  서울혜화경찰서    효제파출소  127.003606  37.574259     종로구 충신동 105번지
# 1480  서울청      서울청      서울청  126.972072  37.575060     종로구 내자동 20-11
#
# [274 rows x 6 columns]

# %%
gudata = []

for i in df_crime['관서명']:
    gudata.append(police.loc[police['서']==i, : ].주소.str.split(' ').values[0][0])
    
gudata
# Out:
# ['중구',
#  '종로구',
#  '중구',
#  '서대문구',
#  '종로구',
#  '용산구',
#  '서울특별시',
#  '동대문구',
#  '마포구',
#  '영등포구',
#  '성동구',
#  '동작구',
#  '광진구',
#  '은평구',
#  '강북구',
#  '금천구',
#  '중랑구',
#  '강남구',
#  '관악구',
#  '강서구',
#  '강동구',
#  '성북구',
#  '구로구',
#  '서초구',
#  '양천구',
#  '송파구',
#  '노원구',
#  '서초구',
#  '은평구',
#  '도봉구',
#  '강남구']
